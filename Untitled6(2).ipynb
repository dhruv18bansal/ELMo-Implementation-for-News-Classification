# %%
# !pip install torch nltk numpy matplotlib seaborn
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 94.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 74.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.8 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 42.5 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import numpy as np
import nltk
from nltk.corpus import brown
from nltk.tokenize import sent_tokenize, word_tokenize
from collections import Counter
import pickle
import os

# Download the Brown corpus if not already downloaded
nltk.download('brown')
nltk.download('punkt')

class ELMoEmbedding(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, num_layers=2, dropout=0.2):
        super(ELMoEmbedding, self).__init__()
        self.embedding_dim = embedding_dim
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers

        # Word embedding layer
        self.word_embeddings = nn.Embedding(vocab_size, embedding_dim)

        # Projection layer to match dimensions
        self.embedding_projection = nn.Linear(embedding_dim, hidden_dim * 2)

        # Bidirectional LSTM layers
        self.lstm_layers = nn.ModuleList([
            nn.LSTM(hidden_dim * 2 if i == 0 else hidden_dim * 2,
                   hidden_dim, batch_first=True, bidirectional=True)
            for i in range(num_layers)
        ])

        self.dropout = nn.Dropout(dropout)

        # Parameters for the weighted sum of LSTM layers
        self.gamma = nn.Parameter(torch.ones(1))
        self.weights = nn.Parameter(torch.ones(num_layers + 1))

        # Linear layers for forward and backward language model
        self.forward_linear = nn.Linear(hidden_dim, vocab_size)
        self.backward_linear = nn.Linear(hidden_dim, vocab_size)

    def forward(self, inputs, return_embeddings=False):
        batch_size, seq_len = inputs.size()

        # Get word embeddings
        embeddings = self.word_embeddings(inputs)  # [batch, seq_len, embedding_dim]

        # Project embeddings to match LSTM dimensions
        projected_embeddings = self.embedding_projection(embeddings)  # [batch, seq_len, hidden_dim * 2]

        layer_outputs = [projected_embeddings]

        # Pass through LSTM layers
        lstm_output = projected_embeddings
        for lstm in self.lstm_layers:
            lstm_output, _ = lstm(self.dropout(lstm_output))
            layer_outputs.append(lstm_output)

        if return_embeddings:
            # Normalize weights
            norm_weights = nn.functional.softmax(self.weights, dim=0)

            # All tensors should now have size (batch, seq_len, hidden_dim * 2)
            weighted_sum = sum(w * tensor for w, tensor in zip(norm_weights, layer_outputs))

            # Scale with gamma
            elmo_embeddings = self.gamma * weighted_sum
            return elmo_embeddings
        else:
            # Extract forward and backward hidden states
            forward_hidden = lstm_output[:, :, :self.hidden_dim]
            backward_hidden = lstm_output[:, :, self.hidden_dim:]

            # Calculate forward and backward language model predictions
            forward_logits = self.forward_linear(forward_hidden)
            backward_logits = self.backward_linear(backward_hidden)
            return forward_logits, backward_logits

class ELMoDataset(Dataset):
    def __init__(self, sentences, word_to_idx, max_len=40):
        self.sentences = sentences
        self.word_to_idx = word_to_idx
        self.max_len = max_len
        self.pad_idx = word_to_idx['<PAD>']
        self.unk_idx = word_to_idx['<UNK>']

    def __len__(self):
        return len(self.sentences)

    def __getitem__(self, idx):
        sentence = self.sentences[idx]

        # Convert words to indices
        indices = [self.word_to_idx.get(word, self.unk_idx) for word in sentence]

        # Truncate or pad sequence to max_len
        if len(indices) > self.max_len:
            indices = indices[:self.max_len]
        else:
            indices = indices + [self.pad_idx] * (self.max_len - len(indices))

        # Create inputs and targets
        inputs = torch.tensor(indices, dtype=torch.long)

        # Forward targets: next word (shifted right, pad at end)
        forward_targets = torch.tensor(indices[1:] + [self.pad_idx], dtype=torch.long)

        # Backward targets: previous word (shifted left, pad at start)
        backward_targets = torch.tensor([self.pad_idx] + indices[:-1], dtype=torch.long)

        return inputs, forward_targets, backward_targets


def preprocess_brown_corpus(min_freq=5, max_vocab_size=30000):
    sentences = []
    for fileid in brown.fileids():
        for sent in brown.sents(fileid):
            # Convert words to lowercase individually and tokenize
            sentences.append([word.lower() for word in sent])

    # Count word frequencies
    word_counts = Counter()
    for sentence in sentences:
        word_counts.update(sentence)

    # Create vocabulary
    vocab = ['<PAD>', '<UNK>']
    for word, count in word_counts.most_common(max_vocab_size - 2):
        if count >= min_freq:
            vocab.append(word)

    word_to_idx = {word: idx for idx, word in enumerate(vocab)}

    return sentences, word_to_idx, vocab


def train_elmo(model, train_loader, device, num_epochs=5, learning_rate=0.001):
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(num_epochs):
        total_loss = 0
        model.train()

        for batch, (inputs, forward_targets, backward_targets) in enumerate(train_loader):
            inputs = inputs.to(device)
            forward_targets = forward_targets.to(device)
            backward_targets = backward_targets.to(device)

            # Forward pass
            forward_logits, backward_logits = model(inputs)

            # Calculate loss
            forward_loss = criterion(forward_logits.view(-1, forward_logits.size(-1)), forward_targets.view(-1))
            backward_loss = criterion(backward_logits.view(-1, backward_logits.size(-1)), backward_targets.view(-1))

            # Total loss
            loss = forward_loss + backward_loss

            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

            if batch % 100 == 0:
                print(f'Epoch {epoch+1}/{num_epochs}, Batch {batch}, Loss: {loss.item():.4f}')

        avg_loss = total_loss / len(train_loader)
        print(f'Epoch {epoch+1}/{num_epochs}, Average Loss: {avg_loss:.4f}')

    return model


def save_model_and_vocab(model, word_to_idx, vocab, model_path='/content/bilstm.pt', vocab_path='/content/vocab.pkl'):
    torch.save(model.state_dict(), model_path)

    with open(vocab_path, 'wb') as f:
        pickle.dump({'word_to_idx': word_to_idx, 'vocab': vocab}, f)


def main():
    # Set device
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}")

    # Preprocess Brown corpus
    print("Preprocessing Brown corpus...")
    sentences, word_to_idx, vocab = preprocess_brown_corpus()

    # Create dataset and dataloader
    print("Creating dataset...")
    dataset = ELMoDataset(sentences, word_to_idx)
    train_loader = DataLoader(dataset, batch_size=64, shuffle=True)

    # Initialize ELMo model
    print("Initializing ELMo model...")
    vocab_size = len(word_to_idx)
    embedding_dim = 1024
    hidden_dim = 512
    model = ELMoEmbedding(vocab_size, embedding_dim, hidden_dim)
    model = model.to(device)

    # Train ELMo model
    print("Training ELMo model...")
    model = train_elmo(model, train_loader, device, num_epochs=5)

    # Save model and vocabulary
    print("Saving model and vocabulary...")
    save_model_and_vocab(model, word_to_idx, vocab)

    print("Training complete!")


if __name__ == "__main__":
    main()
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Using device: cuda
# Preprocessing Brown corpus...
# Creating dataset...
# Initializing ELMo model...
# Training ELMo model...
# Epoch 1/5, Batch 0, Loss: 19.1387
# Epoch 1/5, Batch 100, Loss: 5.1348
# Epoch 1/5, Batch 200, Loss: 3.7968
# Epoch 1/5, Batch 300, Loss: 3.0889
# Epoch 1/5, Batch 400, Loss: 2.4134
# Epoch 1/5, Batch 500, Loss: 2.0703
# Epoch 1/5, Batch 600, Loss: 1.6994
# Epoch 1/5, Batch 700, Loss: 1.2628
# Epoch 1/5, Batch 800, Loss: 0.9557
# Epoch 1/5, Average Loss: 2.6861
# Epoch 2/5, Batch 0, Loss: 0.9129
# Epoch 2/5, Batch 100, Loss: 0.6435
# Epoch 2/5, Batch 200, Loss: 0.6055
# Epoch 2/5, Batch 300, Loss: 0.5563
# Epoch 2/5, Batch 400, Loss: 0.4590
# Epoch 2/5, Batch 500, Loss: 0.3343
# Epoch 2/5, Batch 600, Loss: 0.3518
# Epoch 2/5, Batch 700, Loss: 0.3141
# Epoch 2/5, Batch 800, Loss: 0.2526
# Epoch 2/5, Average Loss: 0.4818
# Epoch 3/5, Batch 0, Loss: 0.1835
# Epoch 3/5, Batch 100, Loss: 0.2167
# Epoch 3/5, Batch 200, Loss: 0.1891
# Epoch 3/5, Batch 300, Loss: 0.1453
# Epoch 3/5, Batch 400, Loss: 0.1244
# Epoch 3/5, Batch 500, Loss: 0.1235
# Epoch 3/5, Batch 600, Loss: 0.0959
# Epoch 3/5, Batch 700, Loss: 0.1030
# Epoch 3/5, Batch 800, Loss: 0.0651
# Epoch 3/5, Average Loss: 0.1282
# Epoch 4/5, Batch 0, Loss: 0.0506
# Epoch 4/5, Batch 100, Loss: 0.0482
# Epoch 4/5, Batch 200, Loss: 0.0570
# Epoch 4/5, Batch 300, Loss: 0.0490
# Epoch 4/5, Batch 400, Loss: 0.0505
# Epoch 4/5, Batch 500, Loss: 0.0429
# Epoch 4/5, Batch 600, Loss: 0.0354
# Epoch 4/5, Batch 700, Loss: 0.0319
# Epoch 4/5, Batch 800, Loss: 0.0251
# Epoch 4/5, Average Loss: 0.0433
# Epoch 5/5, Batch 0, Loss: 0.0292
# Epoch 5/5, Batch 100, Loss: 0.0226
# Epoch 5/5, Batch 200, Loss: 0.0245
# Epoch 5/5, Batch 300, Loss: 0.0259
# Epoch 5/5, Batch 400, Loss: 0.0231
# Epoch 5/5, Batch 500, Loss: 0.0193
# Epoch 5/5, Batch 600, Loss: 0.0178
# Epoch 5/5, Batch 700, Loss: 0.0171
# Epoch 5/5, Batch 800, Loss: 0.0212
# Epoch 5/5, Average Loss: 0.0232
# Saving model and vocabulary...
# Training complete!

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import word_tokenize
import pickle
import os
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Import ELMO model
from ELMO import ELMoEmbedding

nltk.download('punkt_tab')

class NewsClassificationDataset(Dataset):
    def __init__(self, data_path, word_to_idx, max_len=100):
        self.data = pd.read_csv(data_path, on_bad_lines='skip')
        self.word_to_idx = word_to_idx
        self.max_len = max_len
        self.pad_idx = word_to_idx['<PAD>']
        self.unk_idx = word_to_idx['<UNK>']

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        description = str(self.data.iloc[idx]['Description'])  # Ensure string type
        label = self.data.iloc[idx]['Class Index'] - 1  # Adjust to 0-based indexing

        # Tokenize description and handle empty strings
        try:
            tokens = word_tokenize(description.lower())
        except AttributeError:
            tokens = []  # Return empty list if tokenization fails

        # Truncate or pad
        if len(tokens) > self.max_len:
            tokens = tokens[:self.max_len]

        # Convert to indices
        indices = [self.word_to_idx.get(word, self.unk_idx) for word in tokens]

        # Pad to max_len
        indices = indices + [self.pad_idx] * (self.max_len - len(indices))

        return torch.tensor(indices, dtype=torch.long), torch.tensor(label, dtype=torch.long)


class ClassificationModel(nn.Module):
    def __init__(self, elmo_model, hidden_dim, elmo_embedding_dim=1024, num_classes=4, dropout=0.2, lambda_mode='trainable'):
        super(ClassificationModel, self).__init__()
        self.elmo_model = elmo_model
        self.hidden_dim = hidden_dim
        self.elmo_embedding_dim = elmo_embedding_dim
        self.num_classes = num_classes
        self.lambda_mode = lambda_mode

        # Initialize dimension adapter as None - will be set in first forward pass
        self.dim_adapter = None

        # Freeze ELMo parameters
        for param in self.elmo_model.parameters():
            param.requires_grad = False

        # If lambda_mode is 'trainable', we need to unfreeze specific parameters
        if lambda_mode == 'trainable':
            self.elmo_model.gamma.requires_grad = True
            self.elmo_model.weights.requires_grad = True
        elif lambda_mode == 'frozen':
            # Ensure weights are frozen
            self.elmo_model.gamma.requires_grad = False
            self.elmo_model.weights.requires_grad = False
        elif lambda_mode == 'learnable':
            # For learnable function, we'll create a small network to learn the combination
            # We need to calculate the correct input size
            elmo_layer_size = self.elmo_model.hidden_dim * 2  # BiLSTM size
            num_layers = self.elmo_model.num_layers + 1
            input_size = num_layers * elmo_layer_size

            self.combination_network = nn.Sequential(
                nn.Linear(input_size, elmo_layer_size),
                nn.ReLU(),
                nn.Dropout(dropout),
                nn.Linear(elmo_layer_size, hidden_dim * 2),  # Output size matches RNN input
            )

        # RNN for classification
        self.rnn = nn.LSTM(hidden_dim * 2, hidden_dim, batch_first=True, bidirectional=True)

        # Classifier
        self.classifier = nn.Sequential(
            nn.Linear(hidden_dim * 2, hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, num_classes)
        )

    def forward(self, inputs):
        # Get ELMo embeddings
        if self.lambda_mode == 'learnable':
            # Extract all layer outputs
            embeddings = self.elmo_model.word_embeddings(inputs)
            layer_outputs = [embeddings]

            lstm_output = embeddings
            for lstm in self.elmo_model.lstm_layers:
                lstm_output, _ = lstm(lstm_output)
                layer_outputs.append(lstm_output)

            # Concatenate all layer outputs along the last dimension
            concat_outputs = torch.cat(layer_outputs, dim=-1)

            # Apply learnable combination function
            elmo_embeddings = self.combination_network(concat_outputs)
        else:
            # Use the built-in weighted sum
            elmo_embeddings = self.elmo_model(inputs, return_embeddings=True)

            # Initialize the dimension adapter if not already done
            if self.dim_adapter is None:
                input_size = elmo_embeddings.size(-1)
                print(f"Initializing dim_adapter with input size: {input_size}")
                self.dim_adapter = nn.Linear(input_size, self.hidden_dim * 2).to(elmo_embeddings.device)

            # Apply dimension adapter to match RNN input size
            elmo_embeddings = self.dim_adapter(elmo_embeddings)

        # Pass through LSTM
        lstm_output, _ = self.rnn(elmo_embeddings)

        # Global max pooling
        pooled_output = torch.max(lstm_output, dim=1)[0]

        # Pass through classifier
        logits = self.classifier(pooled_output)

        return logits


def train_model(model, train_loader, val_loader, device, num_epochs=10, learning_rate=0.001):
    optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=learning_rate)
    criterion = nn.CrossEntropyLoss()

    best_val_acc = 0

    train_losses = []
    val_accuracies = []

    for epoch in range(num_epochs):
        model.train()
        total_loss = 0

        for batch, (inputs, labels) in enumerate(train_loader):
            inputs = inputs.to(device)
            labels = labels.to(device)

            # Forward pass
            logits = model(inputs)
            loss = criterion(logits, labels)

            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

            if batch % 50 == 0:
                print(f'Epoch {epoch+1}/{num_epochs}, Batch {batch}, Loss: {loss.item():.4f}')

        avg_loss = total_loss / len(train_loader)
        train_losses.append(avg_loss)
        print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {avg_loss:.4f}')

        # Validation
        model.eval()
        val_preds = []
        val_labels = []

        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs = inputs.to(device)
                labels = labels.to(device)

                logits = model(inputs)
                preds = torch.argmax(logits, dim=1)

                val_preds.extend(preds.cpu().numpy())
                val_labels.extend(labels.cpu().numpy())

        val_acc = accuracy_score(val_labels, val_preds)
        val_f1 = f1_score(val_labels, val_preds, average='weighted')
        val_precision = precision_score(val_labels, val_preds, average='weighted')
        val_recall = recall_score(val_labels, val_preds, average='weighted')

        val_accuracies.append(val_acc)

        print(f'Epoch {epoch+1}/{num_epochs}, Val Acc: {val_acc:.4f}, Val F1: {val_f1:.4f}, Val Precision: {val_precision:.4f}, Val Recall: {val_recall:.4f}')

        # Save best model
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save(model.state_dict(), 'classifier.pt')
            print(f'New best model saved with val accuracy: {val_acc:.4f}')

    return train_losses, val_accuracies


def evaluate_model(model, test_loader, device):
    model.eval()
    test_preds = []
    test_labels = []
    test_probs = []

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            logits = model(inputs)
            probs = torch.softmax(logits, dim=1)
            preds = torch.argmax(logits, dim=1)

            test_preds.extend(preds.cpu().numpy())
            test_labels.extend(labels.cpu().numpy())
            test_probs.extend(probs.cpu().numpy())

    # Calculate metrics
    test_acc = accuracy_score(test_labels, test_preds)
    test_f1 = f1_score(test_labels, test_preds, average='weighted')
    test_precision = precision_score(test_labels, test_preds, average='weighted')
    test_recall = recall_score(test_labels, test_preds, average='weighted')

    # Calculate confusion matrix
    conf_matrix = confusion_matrix(test_labels, test_preds)

    print(f'Test Accuracy: {test_acc:.4f}')
    print(f'Test F1 Score: {test_f1:.4f}')
    print(f'Test Precision: {test_precision:.4f}')
    print(f'Test Recall: {test_recall:.4f}')

    # Plot confusion matrix
    plt.figure(figsize=(10, 8))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.savefig('confusion_matrix.png')

    return test_acc, test_f1, test_precision, test_recall, conf_matrix, test_probs


def main():
    # Set device
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}")

    # Load vocabulary
    vocab_path = '/content/vocab.pkl'  # Update to your local path
    with open(vocab_path, 'rb') as f:
        vocab_data = pickle.load(f)
    word_to_idx = vocab_data['word_to_idx']
    vocab = vocab_data['vocab']

    # Load pre-trained ELMo model with corrected dimensions from checkpoint
    vocab_size = len(word_to_idx)
    pretrained_embedding_dim = 1024  # This is the embedding dimension from pretrained weights
    hidden_dim = 512      # Hidden dimension for LSTM layers

    # Create the ELMo model with the correct embedding dimension to match pretrained weights
    elmo_model = ELMoEmbedding(vocab_size, pretrained_embedding_dim, hidden_dim)

    model_path = '/content/bilstm.pt'  # Update to your local path
    try:
        # Load pre-trained weights
        state_dict = torch.load(model_path, map_location=device, weights_only=False)
        # Remove unexpected keys if present
        keys_to_remove = ['embedding_projection.weight', 'embedding_projection.bias']
        for key in keys_to_remove:
            state_dict.pop(key, None)

        # Print state_dict keys for debugging
        # print("Keys in state_dict:", state_dict.keys())

        elmo_model.load_state_dict(state_dict, strict=False)
        print("Successfully loaded pre-trained weights")
    except Exception as e:
        print(f"Warning: Error loading pre-trained weights: {e}")
        print("Initializing with random weights")

    elmo_model = elmo_model.to(device)

    # Add a debugging step to test the ELMo model output shape
    # dummy_input = torch.randint(0, vocab_size, (4, 100)).to(device)
    # with torch.no_grad():
    #     elmo_output = elmo_model(dummy_input, return_embeddings=True)
    #     print(f"ELMo output shape: {elmo_output.shape}")

    # Create datasets and dataloaders
    train_path = '/content/train.csv'  # Update to your local path
    test_path = '/content/test.csv'    # Update to your local path
    train_dataset = NewsClassificationDataset(train_path, word_to_idx)
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

    test_dataset = NewsClassificationDataset(test_path, word_to_idx)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

    # Define lambda modes to test
    lambda_modes = ['trainable', 'frozen', 'learnable']

    results = {}

    for lambda_mode in lambda_modes:
        print(f"\n=== Training with lambda mode: {lambda_mode} ===")

        # Initialize modified classification model with dimension adaptation
        model = ClassificationModel(elmo_model, hidden_dim=hidden_dim,
                                    elmo_embedding_dim=pretrained_embedding_dim,
                                    num_classes=4, lambda_mode=lambda_mode)
        model = model.to(device)

        # Train model
        train_losses, val_accuracies = train_model(model, train_loader, test_loader, device, num_epochs=5)

        # Load best model
        model.load_state_dict(torch.load('classifier.pt', map_location=device))

        # Evaluate model
        test_acc, test_f1, test_precision, test_recall, conf_matrix, test_probs = evaluate_model(model, test_loader, device)

        # Save results
        results[lambda_mode] = {
            'accuracy': test_acc,
            'f1': test_f1,
            'precision': test_precision,
            'recall': test_recall,
            'confusion_matrix': conf_matrix,
            'train_losses': train_losses,
            'val_accuracies': val_accuracies
        }

        # Save model with specific name
        torch.save(model.state_dict(), f'classifier_{lambda_mode}.pt')

    # Determine best lambda mode
    best_lambda_mode = max(results.keys(), key=lambda x: results[x]['accuracy'])
    print(f"\nBest lambda mode: {best_lambda_mode}")
    print(f"Best accuracy: {results[best_lambda_mode]['accuracy']:.4f}")

    # Copy best model to classifier.pt
    os.system(f"cp classifier_{best_lambda_mode}.pt classifier.pt")

    # Plot comparison of lambda modes
    plt.figure(figsize=(12, 6))
    for lambda_mode in lambda_modes:
        plt.plot(results[lambda_mode]['val_accuracies'], label=f"{lambda_mode}")
    plt.title('Validation Accuracy by Lambda Mode')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.savefig('lambda_mode_comparison.png')


if __name__ == "__main__":
    main()
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Using device: cuda
# Successfully loaded pre-trained weights
#
# === Training with lambda mode: trainable ===
# Initializing dim_adapter with input size: 1024
# Epoch 1/5, Batch 0, Loss: 1.3919
# Epoch 1/5, Batch 50, Loss: 1.3467
# Epoch 1/5, Batch 100, Loss: 1.2912
# Epoch 1/5, Batch 150, Loss: 0.8120
# Epoch 1/5, Batch 200, Loss: 0.6799
# Epoch 1/5, Batch 250, Loss: 0.6422
# Epoch 1/5, Batch 300, Loss: 0.4469
# Epoch 1/5, Batch 350, Loss: 0.4288
# Epoch 1/5, Batch 400, Loss: 0.9385
# Epoch 1/5, Batch 450, Loss: 0.6075
# Epoch 1/5, Batch 500, Loss: 0.5720
# Epoch 1/5, Batch 550, Loss: 0.7668
# Epoch 1/5, Batch 600, Loss: 0.5344
# Epoch 1/5, Batch 650, Loss: 0.4424
# Epoch 1/5, Batch 700, Loss: 0.2346
# Epoch 1/5, Batch 750, Loss: 0.5204
# Epoch 1/5, Batch 800, Loss: 0.4165
# Epoch 1/5, Batch 850, Loss: 0.6955
# Epoch 1/5, Batch 900, Loss: 0.5498
# Epoch 1/5, Batch 950, Loss: 0.2640
# Epoch 1/5, Batch 1000, Loss: 0.5203
# Epoch 1/5, Batch 1050, Loss: 0.6860
# Epoch 1/5, Batch 1100, Loss: 0.4830
# Epoch 1/5, Batch 1150, Loss: 0.4050
# Epoch 1/5, Batch 1200, Loss: 0.4164
# Epoch 1/5, Batch 1250, Loss: 0.4159
# Epoch 1/5, Batch 1300, Loss: 0.3407
# Epoch 1/5, Batch 1350, Loss: 0.4238
# Epoch 1/5, Batch 1400, Loss: 0.2730
# Epoch 1/5, Batch 1450, Loss: 0.4045
# Epoch 1/5, Batch 1500, Loss: 0.5350
# Epoch 1/5, Batch 1550, Loss: 0.3480
# Epoch 1/5, Batch 1600, Loss: 0.4928
# Epoch 1/5, Batch 1650, Loss: 0.2275
# Epoch 1/5, Batch 1700, Loss: 0.6781
# Epoch 1/5, Batch 1750, Loss: 0.4739
# Epoch 1/5, Batch 1800, Loss: 0.2376
# Epoch 1/5, Batch 1850, Loss: 0.2722
# Epoch 1/5, Batch 1900, Loss: 0.3043
# Epoch 1/5, Batch 1950, Loss: 0.4971
# Epoch 1/5, Batch 2000, Loss: 0.6112
# Epoch 1/5, Batch 2050, Loss: 0.3713
# Epoch 1/5, Batch 2100, Loss: 0.4261
# Epoch 1/5, Batch 2150, Loss: 0.5375
# Epoch 1/5, Batch 2200, Loss: 0.3516
# Epoch 1/5, Batch 2250, Loss: 0.2902
# Epoch 1/5, Batch 2300, Loss: 0.3803
# Epoch 1/5, Batch 2350, Loss: 0.5318
# Epoch 1/5, Batch 2400, Loss: 0.1724
# Epoch 1/5, Batch 2450, Loss: 0.9617
# Epoch 1/5, Batch 2500, Loss: 0.4294
# Epoch 1/5, Batch 2550, Loss: 0.3719
# Epoch 1/5, Batch 2600, Loss: 0.3986
# Epoch 1/5, Batch 2650, Loss: 0.1817
# Epoch 1/5, Batch 2700, Loss: 0.3761
# Epoch 1/5, Batch 2750, Loss: 0.3480
# Epoch 1/5, Batch 2800, Loss: 0.4691
# Epoch 1/5, Batch 2850, Loss: 0.1918
# Epoch 1/5, Batch 2900, Loss: 0.4072
# Epoch 1/5, Batch 2950, Loss: 0.2653
# Epoch 1/5, Batch 3000, Loss: 0.3090
# Epoch 1/5, Batch 3050, Loss: 0.5303
# Epoch 1/5, Batch 3100, Loss: 0.5548
# Epoch 1/5, Batch 3150, Loss: 0.4043
# Epoch 1/5, Batch 3200, Loss: 0.2746
# Epoch 1/5, Batch 3250, Loss: 0.3037
# Epoch 1/5, Batch 3300, Loss: 0.3046
# Epoch 1/5, Batch 3350, Loss: 0.1972
# Epoch 1/5, Batch 3400, Loss: 0.6158
# Epoch 1/5, Batch 3450, Loss: 0.4054
# Epoch 1/5, Batch 3500, Loss: 0.2607
# Epoch 1/5, Batch 3550, Loss: 0.4429
# Epoch 1/5, Batch 3600, Loss: 0.4911
# Epoch 1/5, Batch 3650, Loss: 0.4291
# Epoch 1/5, Batch 3700, Loss: 0.3245
# Epoch 1/5, Train Loss: 0.4585
# Epoch 1/5, Val Acc: 0.8780, Val F1: 0.8778, Val Precision: 0.8779, Val Recall: 0.8780
# New best model saved with val accuracy: 0.8780
# Epoch 2/5, Batch 0, Loss: 0.7379
# Epoch 2/5, Batch 50, Loss: 0.3960
# Epoch 2/5, Batch 100, Loss: 0.2677
# Epoch 2/5, Batch 150, Loss: 0.1734
# Epoch 2/5, Batch 200, Loss: 0.1587
# Epoch 2/5, Batch 250, Loss: 0.3426
# Epoch 2/5, Batch 300, Loss: 0.3330
# Epoch 2/5, Batch 350, Loss: 0.5783
# Epoch 2/5, Batch 400, Loss: 0.4271
# Epoch 2/5, Batch 450, Loss: 0.5209
# Epoch 2/5, Batch 500, Loss: 0.5250
# Epoch 2/5, Batch 550, Loss: 0.3489
# Epoch 2/5, Batch 600, Loss: 0.3284
# Epoch 2/5, Batch 650, Loss: 0.4232
# Epoch 2/5, Batch 700, Loss: 0.5110
# Epoch 2/5, Batch 750, Loss: 0.3071
# Epoch 2/5, Batch 800, Loss: 0.3257
# Epoch 2/5, Batch 850, Loss: 0.2734
# Epoch 2/5, Batch 900, Loss: 0.2808
# Epoch 2/5, Batch 950, Loss: 0.2086
# Epoch 2/5, Batch 1000, Loss: 0.3381
# Epoch 2/5, Batch 1050, Loss: 0.2457
# Epoch 2/5, Batch 1100, Loss: 0.2511
# Epoch 2/5, Batch 1150, Loss: 0.0813
# Epoch 2/5, Batch 1200, Loss: 0.0483
# Epoch 2/5, Batch 1250, Loss: 0.2939
# Epoch 2/5, Batch 1300, Loss: 0.2992
# Epoch 2/5, Batch 1350, Loss: 0.2308
# Epoch 2/5, Batch 1400, Loss: 0.1602
# Epoch 2/5, Batch 1450, Loss: 0.3984
# Epoch 2/5, Batch 1500, Loss: 0.1066
# Epoch 2/5, Batch 1550, Loss: 0.2821
# Epoch 2/5, Batch 1600, Loss: 0.2722
# Epoch 2/5, Batch 1650, Loss: 0.2126
# Epoch 2/5, Batch 1700, Loss: 0.2959
# Epoch 2/5, Batch 1750, Loss: 0.5354
# Epoch 2/5, Batch 1800, Loss: 0.2534
# Epoch 2/5, Batch 1850, Loss: 0.6453
# Epoch 2/5, Batch 1900, Loss: 0.1995
# Epoch 2/5, Batch 1950, Loss: 0.1790
# Epoch 2/5, Batch 2000, Loss: 0.3635
# Epoch 2/5, Batch 2050, Loss: 0.2245
# Epoch 2/5, Batch 2100, Loss: 0.4045
# Epoch 2/5, Batch 2150, Loss: 0.3229
# Epoch 2/5, Batch 2200, Loss: 0.3724
# Epoch 2/5, Batch 2250, Loss: 0.3901
# Epoch 2/5, Batch 2300, Loss: 0.3439
# Epoch 2/5, Batch 2350, Loss: 0.3630
# Epoch 2/5, Batch 2400, Loss: 0.2630
# Epoch 2/5, Batch 2450, Loss: 0.1879
# Epoch 2/5, Batch 2500, Loss: 0.1737
# Epoch 2/5, Batch 2550, Loss: 0.2946
# Epoch 2/5, Batch 2600, Loss: 0.1939
# Epoch 2/5, Batch 2650, Loss: 0.4312
# Epoch 2/5, Batch 2700, Loss: 0.2891
# Epoch 2/5, Batch 2750, Loss: 0.3645
# Epoch 2/5, Batch 2800, Loss: 0.1241
# Epoch 2/5, Batch 2850, Loss: 0.4356
# Epoch 2/5, Batch 2900, Loss: 0.3074
# Epoch 2/5, Batch 2950, Loss: 0.0798
# Epoch 2/5, Batch 3000, Loss: 0.2750
# Epoch 2/5, Batch 3050, Loss: 0.1633
# Epoch 2/5, Batch 3100, Loss: 0.2834
# Epoch 2/5, Batch 3150, Loss: 0.1163
# Epoch 2/5, Batch 3200, Loss: 0.4519
# Epoch 2/5, Batch 3250, Loss: 0.1174
# Epoch 2/5, Batch 3300, Loss: 0.1923
# Epoch 2/5, Batch 3350, Loss: 0.2644
# Epoch 2/5, Batch 3400, Loss: 0.2931
# Epoch 2/5, Batch 3450, Loss: 0.1420
# Epoch 2/5, Batch 3500, Loss: 0.1603
# Epoch 2/5, Batch 3550, Loss: 0.1231
# Epoch 2/5, Batch 3600, Loss: 0.4379
# Epoch 2/5, Batch 3650, Loss: 0.3177
# Epoch 2/5, Batch 3700, Loss: 0.3700
# Epoch 2/5, Train Loss: 0.3010
# Epoch 2/5, Val Acc: 0.8850, Val F1: 0.8849, Val Precision: 0.8849, Val Recall: 0.8850
# New best model saved with val accuracy: 0.8850
# Epoch 3/5, Batch 0, Loss: 0.1248
# Epoch 3/5, Batch 50, Loss: 0.0758
# Epoch 3/5, Batch 100, Loss: 0.1554
# Epoch 3/5, Batch 150, Loss: 0.1513
# Epoch 3/5, Batch 200, Loss: 0.1314
# Epoch 3/5, Batch 250, Loss: 0.3288
# Epoch 3/5, Batch 300, Loss: 0.2680
# Epoch 3/5, Batch 350, Loss: 0.0794
# Epoch 3/5, Batch 400, Loss: 0.3962
# Epoch 3/5, Batch 450, Loss: 0.2078
# Epoch 3/5, Batch 500, Loss: 0.0851
# Epoch 3/5, Batch 550, Loss: 0.0562
# Epoch 3/5, Batch 600, Loss: 0.1410
# Epoch 3/5, Batch 650, Loss: 0.1343
# Epoch 3/5, Batch 700, Loss: 0.4160
# Epoch 3/5, Batch 750, Loss: 0.0746
# Epoch 3/5, Batch 800, Loss: 0.1992
# Epoch 3/5, Batch 850, Loss: 0.3595
# Epoch 3/5, Batch 900, Loss: 0.0791
# Epoch 3/5, Batch 950, Loss: 0.2415
# Epoch 3/5, Batch 1000, Loss: 0.0885
# Epoch 3/5, Batch 1050, Loss: 0.0646
# Epoch 3/5, Batch 1100, Loss: 0.2378
# Epoch 3/5, Batch 1150, Loss: 0.2420
# Epoch 3/5, Batch 1200, Loss: 0.3759
# Epoch 3/5, Batch 1250, Loss: 0.0969
# Epoch 3/5, Batch 1300, Loss: 0.2956
# Epoch 3/5, Batch 1350, Loss: 0.1860
# Epoch 3/5, Batch 1400, Loss: 0.2007
# Epoch 3/5, Batch 1450, Loss: 0.3807
# Epoch 3/5, Batch 1500, Loss: 0.1339
# Epoch 3/5, Batch 1550, Loss: 0.2102
# Epoch 3/5, Batch 1600, Loss: 0.4034
# Epoch 3/5, Batch 1650, Loss: 0.3107
# Epoch 3/5, Batch 1700, Loss: 0.3158
# Epoch 3/5, Batch 1750, Loss: 0.2275
# Epoch 3/5, Batch 1800, Loss: 0.3015
# Epoch 3/5, Batch 1850, Loss: 0.4531
# Epoch 3/5, Batch 1900, Loss: 0.0936
# Epoch 3/5, Batch 1950, Loss: 0.2439
# Epoch 3/5, Batch 2000, Loss: 0.1336
# Epoch 3/5, Batch 2050, Loss: 0.1454
# Epoch 3/5, Batch 2100, Loss: 0.0556
# Epoch 3/5, Batch 2150, Loss: 0.1468
# Epoch 3/5, Batch 2200, Loss: 0.0626
# Epoch 3/5, Batch 2250, Loss: 0.1101
# Epoch 3/5, Batch 2300, Loss: 0.3291
# Epoch 3/5, Batch 2350, Loss: 0.2143
# Epoch 3/5, Batch 2400, Loss: 0.1721
# Epoch 3/5, Batch 2450, Loss: 0.0745
# Epoch 3/5, Batch 2500, Loss: 0.2343
# Epoch 3/5, Batch 2550, Loss: 0.3135
# Epoch 3/5, Batch 2600, Loss: 0.1577
# Epoch 3/5, Batch 2650, Loss: 0.3270
# Epoch 3/5, Batch 2700, Loss: 0.0963
# Epoch 3/5, Batch 2750, Loss: 0.4402
# Epoch 3/5, Batch 2800, Loss: 0.1321
# Epoch 3/5, Batch 2850, Loss: 0.1816
# Epoch 3/5, Batch 2900, Loss: 0.2506
# Epoch 3/5, Batch 2950, Loss: 0.1436
# Epoch 3/5, Batch 3000, Loss: 0.4342
# Epoch 3/5, Batch 3050, Loss: 0.5227
# Epoch 3/5, Batch 3100, Loss: 0.1462
# Epoch 3/5, Batch 3150, Loss: 0.3014
# Epoch 3/5, Batch 3200, Loss: 0.2383
# Epoch 3/5, Batch 3250, Loss: 0.2786
# Epoch 3/5, Batch 3300, Loss: 0.3120
# Epoch 3/5, Batch 3350, Loss: 0.2229
# Epoch 3/5, Batch 3400, Loss: 0.1928
# Epoch 3/5, Batch 3450, Loss: 0.3561
# Epoch 3/5, Batch 3500, Loss: 0.4365
# Epoch 3/5, Batch 3550, Loss: 0.3221
# Epoch 3/5, Batch 3600, Loss: 0.1066
# Epoch 3/5, Batch 3650, Loss: 0.3274
# Epoch 3/5, Batch 3700, Loss: 0.2916
# Epoch 3/5, Train Loss: 0.2383
# Epoch 3/5, Val Acc: 0.8859, Val F1: 0.8861, Val Precision: 0.8876, Val Recall: 0.8859
# New best model saved with val accuracy: 0.8859
# Epoch 4/5, Batch 0, Loss: 0.1515
# Epoch 4/5, Batch 50, Loss: 0.3936
# Epoch 4/5, Batch 100, Loss: 0.1999
# Epoch 4/5, Batch 150, Loss: 0.2500
# Epoch 4/5, Batch 200, Loss: 0.0756
# Epoch 4/5, Batch 250, Loss: 0.3388
# Epoch 4/5, Batch 300, Loss: 0.1569
# Epoch 4/5, Batch 350, Loss: 0.1257
# Epoch 4/5, Batch 400, Loss: 0.0926
# Epoch 4/5, Batch 450, Loss: 0.0715
# Epoch 4/5, Batch 500, Loss: 0.1214
# Epoch 4/5, Batch 550, Loss: 0.1666
# Epoch 4/5, Batch 600, Loss: 0.1913
# Epoch 4/5, Batch 650, Loss: 0.1758
# Epoch 4/5, Batch 700, Loss: 0.1418
# Epoch 4/5, Batch 750, Loss: 0.2544
# Epoch 4/5, Batch 800, Loss: 0.0986
# Epoch 4/5, Batch 850, Loss: 0.1512
# Epoch 4/5, Batch 900, Loss: 0.1672
# Epoch 4/5, Batch 950, Loss: 0.1977
# Epoch 4/5, Batch 1000, Loss: 0.3481
# Epoch 4/5, Batch 1050, Loss: 0.2017
# Epoch 4/5, Batch 1100, Loss: 0.1153
# Epoch 4/5, Batch 1150, Loss: 0.2657
# Epoch 4/5, Batch 1200, Loss: 0.2214
# Epoch 4/5, Batch 1250, Loss: 0.0618
# Epoch 4/5, Batch 1300, Loss: 0.1646
# Epoch 4/5, Batch 1350, Loss: 0.1190
# Epoch 4/5, Batch 1400, Loss: 0.1027
# Epoch 4/5, Batch 1450, Loss: 0.2182
# Epoch 4/5, Batch 1500, Loss: 0.0945
# Epoch 4/5, Batch 1550, Loss: 0.2210
# Epoch 4/5, Batch 1600, Loss: 0.1028
# Epoch 4/5, Batch 1650, Loss: 0.2102
# Epoch 4/5, Batch 1700, Loss: 0.4263
# Epoch 4/5, Batch 1750, Loss: 0.0706
# Epoch 4/5, Batch 1800, Loss: 0.1805
# Epoch 4/5, Batch 1850, Loss: 0.0575
# Epoch 4/5, Batch 1900, Loss: 0.5409
# Epoch 4/5, Batch 1950, Loss: 0.2249
# Epoch 4/5, Batch 2000, Loss: 0.2046
# Epoch 4/5, Batch 2050, Loss: 0.3647
# Epoch 4/5, Batch 2100, Loss: 0.2980
# Epoch 4/5, Batch 2150, Loss: 0.1994
# Epoch 4/5, Batch 2200, Loss: 0.3293
# Epoch 4/5, Batch 2250, Loss: 0.0889
# Epoch 4/5, Batch 2300, Loss: 0.3274
# Epoch 4/5, Batch 2350, Loss: 0.1293
# Epoch 4/5, Batch 2400, Loss: 0.0688
# Epoch 4/5, Batch 2450, Loss: 0.2458
# Epoch 4/5, Batch 2500, Loss: 0.1566
# Epoch 4/5, Batch 2550, Loss: 0.0642
# Epoch 4/5, Batch 2600, Loss: 0.1254
# Epoch 4/5, Batch 2650, Loss: 0.2933
# Epoch 4/5, Batch 2700, Loss: 0.2324
# Epoch 4/5, Batch 2750, Loss: 0.1087
# Epoch 4/5, Batch 2800, Loss: 0.1079
# Epoch 4/5, Batch 2850, Loss: 0.0971
# Epoch 4/5, Batch 2900, Loss: 0.3138
# Epoch 4/5, Batch 2950, Loss: 0.1965
# Epoch 4/5, Batch 3000, Loss: 0.0811
# Epoch 4/5, Batch 3050, Loss: 0.2178
# Epoch 4/5, Batch 3100, Loss: 0.1924
# Epoch 4/5, Batch 3150, Loss: 0.0893
# Epoch 4/5, Batch 3200, Loss: 0.2384
# Epoch 4/5, Batch 3250, Loss: 0.2286
# Epoch 4/5, Batch 3300, Loss: 0.3216
# Epoch 4/5, Batch 3350, Loss: 0.1987
# Epoch 4/5, Batch 3400, Loss: 0.1094
# Epoch 4/5, Batch 3450, Loss: 0.0926
# Epoch 4/5, Batch 3500, Loss: 0.2095
# Epoch 4/5, Batch 3550, Loss: 0.1471
# Epoch 4/5, Batch 3600, Loss: 0.1842
# Epoch 4/5, Batch 3650, Loss: 0.2438
# Epoch 4/5, Batch 3700, Loss: 0.5726
# Epoch 4/5, Train Loss: 0.1861
# Epoch 4/5, Val Acc: 0.8895, Val F1: 0.8889, Val Precision: 0.8889, Val Recall: 0.8895
# New best model saved with val accuracy: 0.8895
# Epoch 5/5, Batch 0, Loss: 0.1178
# Epoch 5/5, Batch 50, Loss: 0.1936
# Epoch 5/5, Batch 100, Loss: 0.0677
# Epoch 5/5, Batch 150, Loss: 0.2132
# Epoch 5/5, Batch 200, Loss: 0.1216
# Epoch 5/5, Batch 250, Loss: 0.0757
# Epoch 5/5, Batch 300, Loss: 0.0873
# Epoch 5/5, Batch 350, Loss: 0.1340
# Epoch 5/5, Batch 400, Loss: 0.0589
# Epoch 5/5, Batch 450, Loss: 0.0893
# Epoch 5/5, Batch 500, Loss: 0.1020
# Epoch 5/5, Batch 550, Loss: 0.2260
# Epoch 5/5, Batch 600, Loss: 0.1002
# Epoch 5/5, Batch 650, Loss: 0.1186
# Epoch 5/5, Batch 700, Loss: 0.1552
# Epoch 5/5, Batch 750, Loss: 0.2003
# Epoch 5/5, Batch 800, Loss: 0.1059
# Epoch 5/5, Batch 850, Loss: 0.1535
# Epoch 5/5, Batch 900, Loss: 0.1987
# Epoch 5/5, Batch 950, Loss: 0.0582
# Epoch 5/5, Batch 1000, Loss: 0.3269
# Epoch 5/5, Batch 1050, Loss: 0.1356
# Epoch 5/5, Batch 1100, Loss: 0.1119
# Epoch 5/5, Batch 1150, Loss: 0.1257
# Epoch 5/5, Batch 1200, Loss: 0.1875
# Epoch 5/5, Batch 1250, Loss: 0.1605
# Epoch 5/5, Batch 1300, Loss: 0.1516
# Epoch 5/5, Batch 1350, Loss: 0.1232
# Epoch 5/5, Batch 1400, Loss: 0.0314
# Epoch 5/5, Batch 1450, Loss: 0.0352
# Epoch 5/5, Batch 1500, Loss: 0.4517
# Epoch 5/5, Batch 1550, Loss: 0.2833
# Epoch 5/5, Batch 1600, Loss: 0.0508
# Epoch 5/5, Batch 1650, Loss: 0.1544
# Epoch 5/5, Batch 1700, Loss: 0.0816
# Epoch 5/5, Batch 1750, Loss: 0.1714
# Epoch 5/5, Batch 1800, Loss: 0.1374
# Epoch 5/5, Batch 1850, Loss: 0.3703
# Epoch 5/5, Batch 1900, Loss: 0.0705
# Epoch 5/5, Batch 1950, Loss: 0.1354
# Epoch 5/5, Batch 2000, Loss: 0.1026
# Epoch 5/5, Batch 2050, Loss: 0.1976
# Epoch 5/5, Batch 2100, Loss: 0.0419
# Epoch 5/5, Batch 2150, Loss: 0.2956
# Epoch 5/5, Batch 2200, Loss: 0.2220
# Epoch 5/5, Batch 2250, Loss: 0.0400
# Epoch 5/5, Batch 2300, Loss: 0.0376
# Epoch 5/5, Batch 2350, Loss: 0.2112
# Epoch 5/5, Batch 2400, Loss: 0.0547
# Epoch 5/5, Batch 2450, Loss: 0.4575
# Epoch 5/5, Batch 2500, Loss: 0.1138
# Epoch 5/5, Batch 2550, Loss: 0.1589
# Epoch 5/5, Batch 2600, Loss: 0.3020
# Epoch 5/5, Batch 2650, Loss: 0.0616
# Epoch 5/5, Batch 2700, Loss: 0.2453
# Epoch 5/5, Batch 2750, Loss: 0.2586
# Epoch 5/5, Batch 2800, Loss: 0.0880
# Epoch 5/5, Batch 2850, Loss: 0.0521
# Epoch 5/5, Batch 2900, Loss: 0.1299
# Epoch 5/5, Batch 2950, Loss: 0.0622
# Epoch 5/5, Batch 3000, Loss: 0.0752
# Epoch 5/5, Batch 3050, Loss: 0.3192
# Epoch 5/5, Batch 3100, Loss: 0.0449
# Epoch 5/5, Batch 3150, Loss: 0.1316
# Epoch 5/5, Batch 3200, Loss: 0.0942
# Epoch 5/5, Batch 3250, Loss: 0.1254
# Epoch 5/5, Batch 3300, Loss: 0.1159
# Epoch 5/5, Batch 3350, Loss: 0.0698
# Epoch 5/5, Batch 3400, Loss: 0.0747
# Epoch 5/5, Batch 3450, Loss: 0.4008
# Epoch 5/5, Batch 3500, Loss: 0.1242
# Epoch 5/5, Batch 3550, Loss: 0.0678
# Epoch 5/5, Batch 3600, Loss: 0.1308
# Epoch 5/5, Batch 3650, Loss: 0.1226
# Epoch 5/5, Batch 3700, Loss: 0.1293
# Epoch 5/5, Train Loss: 0.1400
# Epoch 5/5, Val Acc: 0.8929, Val F1: 0.8927, Val Precision: 0.8931, Val Recall: 0.8929
# New best model saved with val accuracy: 0.8929
# Test Accuracy: 0.8929
# Test F1 Score: 0.8927
# Test Precision: 0.8931
# Test Recall: 0.8929
#
# === Training with lambda mode: frozen ===
# Initializing dim_adapter with input size: 1024
# Epoch 1/5, Batch 0, Loss: 1.3832
# Epoch 1/5, Batch 50, Loss: 1.2377
# Epoch 1/5, Batch 100, Loss: 0.5499
# Epoch 1/5, Batch 150, Loss: 0.7329
# Epoch 1/5, Batch 200, Loss: 0.6292
# Epoch 1/5, Batch 250, Loss: 0.4940
# Epoch 1/5, Batch 300, Loss: 0.6357
# Epoch 1/5, Batch 350, Loss: 0.9297
# Epoch 1/5, Batch 400, Loss: 0.6542
# Epoch 1/5, Batch 450, Loss: 0.5267
# Epoch 1/5, Batch 500, Loss: 0.4875
# Epoch 1/5, Batch 550, Loss: 0.3606
# Epoch 1/5, Batch 600, Loss: 0.2532
# Epoch 1/5, Batch 650, Loss: 0.4876
# Epoch 1/5, Batch 700, Loss: 0.4834
# Epoch 1/5, Batch 750, Loss: 0.3854
# Epoch 1/5, Batch 800, Loss: 0.4191
# Epoch 1/5, Batch 850, Loss: 0.5480
# Epoch 1/5, Batch 900, Loss: 0.4532
# Epoch 1/5, Batch 950, Loss: 0.4611
# Epoch 1/5, Batch 1000, Loss: 0.1671
# Epoch 1/5, Batch 1050, Loss: 0.6886
# Epoch 1/5, Batch 1100, Loss: 0.5586
# Epoch 1/5, Batch 1150, Loss: 0.3175
# Epoch 1/5, Batch 1200, Loss: 0.3171
# Epoch 1/5, Batch 1250, Loss: 0.4163
# Epoch 1/5, Batch 1300, Loss: 0.4409
# Epoch 1/5, Batch 1350, Loss: 0.3774
# Epoch 1/5, Batch 1400, Loss: 0.5066
# Epoch 1/5, Batch 1450, Loss: 0.3890
# Epoch 1/5, Batch 1500, Loss: 0.4154
# Epoch 1/5, Batch 1550, Loss: 0.4112
# Epoch 1/5, Batch 1600, Loss: 0.4436
# Epoch 1/5, Batch 1650, Loss: 0.5854
# Epoch 1/5, Batch 1700, Loss: 0.3884
# Epoch 1/5, Batch 1750, Loss: 0.3998
# Epoch 1/5, Batch 1800, Loss: 0.1866
# Epoch 1/5, Batch 1850, Loss: 0.2404
# Epoch 1/5, Batch 1900, Loss: 0.4890
# Epoch 1/5, Batch 1950, Loss: 0.6013
# Epoch 1/5, Batch 2000, Loss: 0.3970
# Epoch 1/5, Batch 2050, Loss: 0.4809
# Epoch 1/5, Batch 2100, Loss: 0.3172
# Epoch 1/5, Batch 2150, Loss: 0.3853
# Epoch 1/5, Batch 2200, Loss: 0.1531
# Epoch 1/5, Batch 2250, Loss: 0.5721
# Epoch 1/5, Batch 2300, Loss: 0.2434
# Epoch 1/5, Batch 2350, Loss: 0.1794
# Epoch 1/5, Batch 2400, Loss: 0.2986
# Epoch 1/5, Batch 2450, Loss: 0.5184
# Epoch 1/5, Batch 2500, Loss: 0.5881
# Epoch 1/5, Batch 2550, Loss: 0.3213
# Epoch 1/5, Batch 2600, Loss: 0.4547
# Epoch 1/5, Batch 2650, Loss: 0.2653
# Epoch 1/5, Batch 2700, Loss: 0.2401
# Epoch 1/5, Batch 2750, Loss: 0.2464
# Epoch 1/5, Batch 2800, Loss: 0.2508
# Epoch 1/5, Batch 2850, Loss: 0.4205
# Epoch 1/5, Batch 2900, Loss: 0.4155
# Epoch 1/5, Batch 2950, Loss: 0.3132
# Epoch 1/5, Batch 3000, Loss: 0.4194
# Epoch 1/5, Batch 3050, Loss: 0.3851
# Epoch 1/5, Batch 3100, Loss: 0.3703
# Epoch 1/5, Batch 3150, Loss: 0.2627
# Epoch 1/5, Batch 3200, Loss: 0.3341
# Epoch 1/5, Batch 3250, Loss: 0.3355
# Epoch 1/5, Batch 3300, Loss: 0.3733
# Epoch 1/5, Batch 3350, Loss: 0.4539
# Epoch 1/5, Batch 3400, Loss: 0.3413
# Epoch 1/5, Batch 3450, Loss: 0.3141
# Epoch 1/5, Batch 3500, Loss: 0.2986
# Epoch 1/5, Batch 3550, Loss: 0.3460
# Epoch 1/5, Batch 3600, Loss: 0.3925
# Epoch 1/5, Batch 3650, Loss: 0.2767
# Epoch 1/5, Batch 3700, Loss: 0.4423
# Epoch 1/5, Train Loss: 0.4186
# Epoch 1/5, Val Acc: 0.8814, Val F1: 0.8813, Val Precision: 0.8817, Val Recall: 0.8814
# New best model saved with val accuracy: 0.8814
# Epoch 2/5, Batch 0, Loss: 0.2024
# Epoch 2/5, Batch 50, Loss: 0.3245
# Epoch 2/5, Batch 100, Loss: 0.4416
# Epoch 2/5, Batch 150, Loss: 0.1935
# Epoch 2/5, Batch 200, Loss: 0.1226
# Epoch 2/5, Batch 250, Loss: 0.2438
# Epoch 2/5, Batch 300, Loss: 0.1179
# Epoch 2/5, Batch 350, Loss: 0.4895
# Epoch 2/5, Batch 400, Loss: 0.3161
# Epoch 2/5, Batch 450, Loss: 0.4327
# Epoch 2/5, Batch 500, Loss: 0.5788
# Epoch 2/5, Batch 550, Loss: 0.8291
# Epoch 2/5, Batch 600, Loss: 0.1433
# Epoch 2/5, Batch 650, Loss: 0.3201
# Epoch 2/5, Batch 700, Loss: 0.1693
# Epoch 2/5, Batch 750, Loss: 0.1210
# Epoch 2/5, Batch 800, Loss: 0.1505
# Epoch 2/5, Batch 850, Loss: 0.1939
# Epoch 2/5, Batch 900, Loss: 0.4345
# Epoch 2/5, Batch 950, Loss: 0.0821
# Epoch 2/5, Batch 1000, Loss: 0.2667
# Epoch 2/5, Batch 1050, Loss: 0.2145
# Epoch 2/5, Batch 1100, Loss: 0.1903
# Epoch 2/5, Batch 1150, Loss: 0.2131
# Epoch 2/5, Batch 1200, Loss: 0.1893
# Epoch 2/5, Batch 1250, Loss: 0.2427
# Epoch 2/5, Batch 1300, Loss: 0.2909
# Epoch 2/5, Batch 1350, Loss: 0.1455
# Epoch 2/5, Batch 1400, Loss: 0.5683
# Epoch 2/5, Batch 1450, Loss: 0.2372
# Epoch 2/5, Batch 1500, Loss: 0.2320
# Epoch 2/5, Batch 1550, Loss: 0.2055
# Epoch 2/5, Batch 1600, Loss: 0.2017
# Epoch 2/5, Batch 1650, Loss: 0.4587
# Epoch 2/5, Batch 1700, Loss: 0.1620
# Epoch 2/5, Batch 1750, Loss: 0.1891
# Epoch 2/5, Batch 1800, Loss: 0.1392
# Epoch 2/5, Batch 1850, Loss: 0.2925
# Epoch 2/5, Batch 1900, Loss: 0.5017
# Epoch 2/5, Batch 1950, Loss: 0.2591
# Epoch 2/5, Batch 2000, Loss: 0.2463
# Epoch 2/5, Batch 2050, Loss: 0.2314
# Epoch 2/5, Batch 2100, Loss: 0.3389
# Epoch 2/5, Batch 2150, Loss: 0.2707
# Epoch 2/5, Batch 2200, Loss: 0.2590
# Epoch 2/5, Batch 2250, Loss: 0.2483
# Epoch 2/5, Batch 2300, Loss: 0.2971
# Epoch 2/5, Batch 2350, Loss: 0.1403
# Epoch 2/5, Batch 2400, Loss: 0.2214
# Epoch 2/5, Batch 2450, Loss: 0.2692
# Epoch 2/5, Batch 2500, Loss: 0.3526
# Epoch 2/5, Batch 2550, Loss: 0.3387
# Epoch 2/5, Batch 2600, Loss: 0.1808
# Epoch 2/5, Batch 2650, Loss: 0.0931
# Epoch 2/5, Batch 2700, Loss: 0.6315
# Epoch 2/5, Batch 2750, Loss: 0.2805
# Epoch 2/5, Batch 2800, Loss: 0.2391
# Epoch 2/5, Batch 2850, Loss: 0.0725
# Epoch 2/5, Batch 2900, Loss: 0.4135
# Epoch 2/5, Batch 2950, Loss: 0.0940
# Epoch 2/5, Batch 3000, Loss: 0.0979
# Epoch 2/5, Batch 3050, Loss: 0.2957
# Epoch 2/5, Batch 3100, Loss: 0.2018
# Epoch 2/5, Batch 3150, Loss: 0.2060
# Epoch 2/5, Batch 3200, Loss: 0.1637
# Epoch 2/5, Batch 3250, Loss: 0.5015
# Epoch 2/5, Batch 3300, Loss: 0.3931
# Epoch 2/5, Batch 3350, Loss: 0.3217
# Epoch 2/5, Batch 3400, Loss: 0.4155
# Epoch 2/5, Batch 3450, Loss: 0.6270
# Epoch 2/5, Batch 3500, Loss: 0.2178
# Epoch 2/5, Batch 3550, Loss: 0.3901
# Epoch 2/5, Batch 3600, Loss: 0.1916
# Epoch 2/5, Batch 3650, Loss: 0.1656
# Epoch 2/5, Batch 3700, Loss: 0.2171
# Epoch 2/5, Train Loss: 0.2808
# Epoch 2/5, Val Acc: 0.8874, Val F1: 0.8870, Val Precision: 0.8870, Val Recall: 0.8874
# New best model saved with val accuracy: 0.8874
# Epoch 3/5, Batch 0, Loss: 0.3005
# Epoch 3/5, Batch 50, Loss: 0.1615
# Epoch 3/5, Batch 100, Loss: 0.0848
# Epoch 3/5, Batch 150, Loss: 0.1428
# Epoch 3/5, Batch 200, Loss: 0.1104
# Epoch 3/5, Batch 250, Loss: 0.1777
# Epoch 3/5, Batch 300, Loss: 0.0475
# Epoch 3/5, Batch 350, Loss: 0.3584
# Epoch 3/5, Batch 400, Loss: 0.1738
# Epoch 3/5, Batch 450, Loss: 0.1499
# Epoch 3/5, Batch 500, Loss: 0.2362
# Epoch 3/5, Batch 550, Loss: 0.0449
# Epoch 3/5, Batch 600, Loss: 0.2807
# Epoch 3/5, Batch 650, Loss: 0.1255
# Epoch 3/5, Batch 700, Loss: 0.3386
# Epoch 3/5, Batch 750, Loss: 0.0197
# Epoch 3/5, Batch 800, Loss: 0.1297
# Epoch 3/5, Batch 850, Loss: 0.1643
# Epoch 3/5, Batch 900, Loss: 0.4134
# Epoch 3/5, Batch 950, Loss: 0.3687
# Epoch 3/5, Batch 1000, Loss: 0.0742
# Epoch 3/5, Batch 1050, Loss: 0.2470
# Epoch 3/5, Batch 1100, Loss: 0.1229
# Epoch 3/5, Batch 1150, Loss: 0.0690
# Epoch 3/5, Batch 1200, Loss: 0.1224
# Epoch 3/5, Batch 1250, Loss: 0.1530
# Epoch 3/5, Batch 1300, Loss: 0.0686
# Epoch 3/5, Batch 1350, Loss: 0.2774
# Epoch 3/5, Batch 1400, Loss: 0.2258
# Epoch 3/5, Batch 1450, Loss: 0.2368
# Epoch 3/5, Batch 1500, Loss: 0.2618
# Epoch 3/5, Batch 1550, Loss: 0.2236
# Epoch 3/5, Batch 1600, Loss: 0.0652
# Epoch 3/5, Batch 1650, Loss: 0.1127
# Epoch 3/5, Batch 1700, Loss: 0.3434
# Epoch 3/5, Batch 1750, Loss: 0.1060
# Epoch 3/5, Batch 1800, Loss: 0.2851
# Epoch 3/5, Batch 1850, Loss: 0.1995
# Epoch 3/5, Batch 1900, Loss: 0.3356
# Epoch 3/5, Batch 1950, Loss: 0.0291
# Epoch 3/5, Batch 2000, Loss: 0.1453
# Epoch 3/5, Batch 2050, Loss: 0.2159
# Epoch 3/5, Batch 2100, Loss: 0.3397
# Epoch 3/5, Batch 2150, Loss: 0.2061
# Epoch 3/5, Batch 2200, Loss: 0.1199
# Epoch 3/5, Batch 2250, Loss: 0.2162
# Epoch 3/5, Batch 2300, Loss: 0.0683
# Epoch 3/5, Batch 2350, Loss: 0.0719
# Epoch 3/5, Batch 2400, Loss: 0.2308
# Epoch 3/5, Batch 2450, Loss: 0.2869
# Epoch 3/5, Batch 2500, Loss: 0.2707
# Epoch 3/5, Batch 2550, Loss: 0.2170
# Epoch 3/5, Batch 2600, Loss: 0.2726
# Epoch 3/5, Batch 2650, Loss: 0.1166
# Epoch 3/5, Batch 2700, Loss: 0.3671
# Epoch 3/5, Batch 2750, Loss: 0.3262
# Epoch 3/5, Batch 2800, Loss: 0.0329
# Epoch 3/5, Batch 2850, Loss: 0.1656
# Epoch 3/5, Batch 2900, Loss: 0.1899
# Epoch 3/5, Batch 2950, Loss: 0.2981
# Epoch 3/5, Batch 3000, Loss: 0.1813
# Epoch 3/5, Batch 3050, Loss: 0.1891
# Epoch 3/5, Batch 3100, Loss: 0.1924
# Epoch 3/5, Batch 3150, Loss: 0.3773
# Epoch 3/5, Batch 3200, Loss: 0.1746
# Epoch 3/5, Batch 3250, Loss: 0.1245
# Epoch 3/5, Batch 3300, Loss: 0.1179
# Epoch 3/5, Batch 3350, Loss: 0.0356
# Epoch 3/5, Batch 3400, Loss: 0.2883
# Epoch 3/5, Batch 3450, Loss: 0.0842
# Epoch 3/5, Batch 3500, Loss: 0.1346
# Epoch 3/5, Batch 3550, Loss: 0.3853
# Epoch 3/5, Batch 3600, Loss: 0.1181
# Epoch 3/5, Batch 3650, Loss: 0.3100
# Epoch 3/5, Batch 3700, Loss: 0.3326
# Epoch 3/5, Train Loss: 0.2103
# Epoch 3/5, Val Acc: 0.8930, Val F1: 0.8930, Val Precision: 0.8930, Val Recall: 0.8930
# New best model saved with val accuracy: 0.8930
# Epoch 4/5, Batch 0, Loss: 0.0863
# Epoch 4/5, Batch 50, Loss: 0.1925
# Epoch 4/5, Batch 100, Loss: 0.0586
# Epoch 4/5, Batch 150, Loss: 0.1068
# Epoch 4/5, Batch 200, Loss: 0.2085
# Epoch 4/5, Batch 250, Loss: 0.1189
# Epoch 4/5, Batch 300, Loss: 0.1330
# Epoch 4/5, Batch 350, Loss: 0.1350
# Epoch 4/5, Batch 400, Loss: 0.1404
# Epoch 4/5, Batch 450, Loss: 0.1093
# Epoch 4/5, Batch 500, Loss: 0.0807
# Epoch 4/5, Batch 550, Loss: 0.0317
# Epoch 4/5, Batch 600, Loss: 0.0619
# Epoch 4/5, Batch 650, Loss: 0.2233
# Epoch 4/5, Batch 700, Loss: 0.0412
# Epoch 4/5, Batch 750, Loss: 0.1942
# Epoch 4/5, Batch 800, Loss: 0.1869
# Epoch 4/5, Batch 850, Loss: 0.1294
# Epoch 4/5, Batch 900, Loss: 0.1194
# Epoch 4/5, Batch 950, Loss: 0.1882
# Epoch 4/5, Batch 1000, Loss: 0.1919
# Epoch 4/5, Batch 1050, Loss: 0.0406
# Epoch 4/5, Batch 1100, Loss: 0.0929
# Epoch 4/5, Batch 1150, Loss: 0.0662
# Epoch 4/5, Batch 1200, Loss: 0.2181
# Epoch 4/5, Batch 1250, Loss: 0.0814
# Epoch 4/5, Batch 1300, Loss: 0.1067
# Epoch 4/5, Batch 1350, Loss: 0.0977
# Epoch 4/5, Batch 1400, Loss: 0.0688
# Epoch 4/5, Batch 1450, Loss: 0.1025
# Epoch 4/5, Batch 1500, Loss: 0.1477
# Epoch 4/5, Batch 1550, Loss: 0.1094
# Epoch 4/5, Batch 1600, Loss: 0.0599
# Epoch 4/5, Batch 1650, Loss: 0.1064
# Epoch 4/5, Batch 1700, Loss: 0.1446
# Epoch 4/5, Batch 1750, Loss: 0.0707
# Epoch 4/5, Batch 1800, Loss: 0.1663
# Epoch 4/5, Batch 1850, Loss: 0.0486
# Epoch 4/5, Batch 1900, Loss: 0.1947
# Epoch 4/5, Batch 1950, Loss: 0.0169
# Epoch 4/5, Batch 2000, Loss: 0.1416
# Epoch 4/5, Batch 2050, Loss: 0.0805
# Epoch 4/5, Batch 2100, Loss: 0.3021
# Epoch 4/5, Batch 2150, Loss: 0.1710
# Epoch 4/5, Batch 2200, Loss: 0.0805
# Epoch 4/5, Batch 2250, Loss: 0.0869
# Epoch 4/5, Batch 2300, Loss: 0.3454
# Epoch 4/5, Batch 2350, Loss: 0.0335
# Epoch 4/5, Batch 2400, Loss: 0.3830
# Epoch 4/5, Batch 2450, Loss: 0.2731
# Epoch 4/5, Batch 2500, Loss: 0.1792
# Epoch 4/5, Batch 2550, Loss: 0.3129
# Epoch 4/5, Batch 2600, Loss: 0.1431
# Epoch 4/5, Batch 2650, Loss: 0.1390
# Epoch 4/5, Batch 2700, Loss: 0.2163
# Epoch 4/5, Batch 2750, Loss: 0.0964
# Epoch 4/5, Batch 2800, Loss: 0.0752
# Epoch 4/5, Batch 2850, Loss: 0.0443
# Epoch 4/5, Batch 2900, Loss: 0.1212
# Epoch 4/5, Batch 2950, Loss: 0.0430
# Epoch 4/5, Batch 3000, Loss: 0.2719
# Epoch 4/5, Batch 3050, Loss: 0.2967
# Epoch 4/5, Batch 3100, Loss: 0.1963
# Epoch 4/5, Batch 3150, Loss: 0.1319
# Epoch 4/5, Batch 3200, Loss: 0.0690
# Epoch 4/5, Batch 3250, Loss: 0.1659
# Epoch 4/5, Batch 3300, Loss: 0.4296
# Epoch 4/5, Batch 3350, Loss: 0.1679
# Epoch 4/5, Batch 3400, Loss: 0.2518
# Epoch 4/5, Batch 3450, Loss: 0.0250
# Epoch 4/5, Batch 3500, Loss: 0.0906
# Epoch 4/5, Batch 3550, Loss: 0.1326
# Epoch 4/5, Batch 3600, Loss: 0.1026
# Epoch 4/5, Batch 3650, Loss: 0.0558
# Epoch 4/5, Batch 3700, Loss: 0.0314
# Epoch 4/5, Train Loss: 0.1567
# Epoch 4/5, Val Acc: 0.8891, Val F1: 0.8892, Val Precision: 0.8897, Val Recall: 0.8891
# Epoch 5/5, Batch 0, Loss: 0.2404
# Epoch 5/5, Batch 50, Loss: 0.0745
# Epoch 5/5, Batch 100, Loss: 0.2212
# Epoch 5/5, Batch 150, Loss: 0.0874
# Epoch 5/5, Batch 200, Loss: 0.1421
# Epoch 5/5, Batch 250, Loss: 0.0930
# Epoch 5/5, Batch 300, Loss: 0.1669
# Epoch 5/5, Batch 350, Loss: 0.0554
# Epoch 5/5, Batch 400, Loss: 0.0529
# Epoch 5/5, Batch 450, Loss: 0.0129
# Epoch 5/5, Batch 500, Loss: 0.0711
# Epoch 5/5, Batch 550, Loss: 0.0466
# Epoch 5/5, Batch 600, Loss: 0.1404
# Epoch 5/5, Batch 650, Loss: 0.0170
# Epoch 5/5, Batch 700, Loss: 0.0278
# Epoch 5/5, Batch 750, Loss: 0.1997
# Epoch 5/5, Batch 800, Loss: 0.1565
# Epoch 5/5, Batch 850, Loss: 0.1453
# Epoch 5/5, Batch 900, Loss: 0.0876
# Epoch 5/5, Batch 950, Loss: 0.0410
# Epoch 5/5, Batch 1000, Loss: 0.0305
# Epoch 5/5, Batch 1050, Loss: 0.0984
# Epoch 5/5, Batch 1100, Loss: 0.1936
# Epoch 5/5, Batch 1150, Loss: 0.0283
# Epoch 5/5, Batch 1200, Loss: 0.2756
# Epoch 5/5, Batch 1250, Loss: 0.1266
# Epoch 5/5, Batch 1300, Loss: 0.1536
# Epoch 5/5, Batch 1350, Loss: 0.3053
# Epoch 5/5, Batch 1400, Loss: 0.1062
# Epoch 5/5, Batch 1450, Loss: 0.1246
# Epoch 5/5, Batch 1500, Loss: 0.1309
# Epoch 5/5, Batch 1550, Loss: 0.0071
# Epoch 5/5, Batch 1600, Loss: 0.0343
# Epoch 5/5, Batch 1650, Loss: 0.0452
# Epoch 5/5, Batch 1700, Loss: 0.3284
# Epoch 5/5, Batch 1750, Loss: 0.3677
# Epoch 5/5, Batch 1800, Loss: 0.1271
# Epoch 5/5, Batch 1850, Loss: 0.0388
# Epoch 5/5, Batch 1900, Loss: 0.2633
# Epoch 5/5, Batch 1950, Loss: 0.0386
# Epoch 5/5, Batch 2000, Loss: 0.0932
# Epoch 5/5, Batch 2050, Loss: 0.0492
# Epoch 5/5, Batch 2100, Loss: 0.2887
# Epoch 5/5, Batch 2150, Loss: 0.1584
# Epoch 5/5, Batch 2200, Loss: 0.2726
# Epoch 5/5, Batch 2250, Loss: 0.1089
# Epoch 5/5, Batch 2300, Loss: 0.1198
# Epoch 5/5, Batch 2350, Loss: 0.1999
# Epoch 5/5, Batch 2400, Loss: 0.0612
# Epoch 5/5, Batch 2450, Loss: 0.0329
# Epoch 5/5, Batch 2500, Loss: 0.1133
# Epoch 5/5, Batch 2550, Loss: 0.0334
# Epoch 5/5, Batch 2600, Loss: 0.0456
# Epoch 5/5, Batch 2650, Loss: 0.1749
# Epoch 5/5, Batch 2700, Loss: 0.1172
# Epoch 5/5, Batch 2750, Loss: 0.0645
# Epoch 5/5, Batch 2800, Loss: 0.1226
# Epoch 5/5, Batch 2850, Loss: 0.0684
# Epoch 5/5, Batch 2900, Loss: 0.0337
# Epoch 5/5, Batch 2950, Loss: 0.0787
# Epoch 5/5, Batch 3000, Loss: 0.0254
# Epoch 5/5, Batch 3050, Loss: 0.0393
# Epoch 5/5, Batch 3100, Loss: 0.0773
# Epoch 5/5, Batch 3150, Loss: 0.1172
# Epoch 5/5, Batch 3200, Loss: 0.0417
# Epoch 5/5, Batch 3250, Loss: 0.0590
# Epoch 5/5, Batch 3300, Loss: 0.2007
# Epoch 5/5, Batch 3350, Loss: 0.0163
# Epoch 5/5, Batch 3400, Loss: 0.0487
# Epoch 5/5, Batch 3450, Loss: 0.0648
# Epoch 5/5, Batch 3500, Loss: 0.0808
# Epoch 5/5, Batch 3550, Loss: 0.1494
# Epoch 5/5, Batch 3600, Loss: 0.3137
# Epoch 5/5, Batch 3650, Loss: 0.0971
# Epoch 5/5, Batch 3700, Loss: 0.0836
# Epoch 5/5, Train Loss: 0.1159
# Epoch 5/5, Val Acc: 0.8824, Val F1: 0.8824, Val Precision: 0.8841, Val Recall: 0.8824
# Test Accuracy: 0.8930
# Test F1 Score: 0.8930
# Test Precision: 0.8930
# Test Recall: 0.8930
#
# === Training with lambda mode: learnable ===
# Epoch 1/5, Batch 0, Loss: 1.3908
# Epoch 1/5, Batch 50, Loss: 1.3561
# Epoch 1/5, Batch 100, Loss: 1.3786
# Epoch 1/5, Batch 150, Loss: 1.3565
# Epoch 1/5, Batch 200, Loss: 1.3759
# Epoch 1/5, Batch 250, Loss: 1.3599
# Epoch 1/5, Batch 300, Loss: 1.4421
# Epoch 1/5, Batch 350, Loss: 1.2700
# Epoch 1/5, Batch 400, Loss: 1.3194
# Epoch 1/5, Batch 450, Loss: 1.2293
# Epoch 1/5, Batch 500, Loss: 1.1375
# Epoch 1/5, Batch 550, Loss: 1.2270
# Epoch 1/5, Batch 600, Loss: 1.2645
# Epoch 1/5, Batch 650, Loss: 1.2776
# Epoch 1/5, Batch 700, Loss: 1.2198
# Epoch 1/5, Batch 750, Loss: 1.2327
# Epoch 1/5, Batch 800, Loss: 1.3537
# Epoch 1/5, Batch 850, Loss: 1.2906
# Epoch 1/5, Batch 900, Loss: 1.2306
# Epoch 1/5, Batch 950, Loss: 1.2462
# Epoch 1/5, Batch 1000, Loss: 1.3279
# Epoch 1/5, Batch 1050, Loss: 1.0923
# Epoch 1/5, Batch 1100, Loss: 1.0210
# Epoch 1/5, Batch 1150, Loss: 1.1948
# Epoch 1/5, Batch 1200, Loss: 1.1164
# Epoch 1/5, Batch 1250, Loss: 1.2551
# Epoch 1/5, Batch 1300, Loss: 1.1285
# Epoch 1/5, Batch 1350, Loss: 1.1146
# Epoch 1/5, Batch 1400, Loss: 1.1643
# Epoch 1/5, Batch 1450, Loss: 1.0641
# Epoch 1/5, Batch 1500, Loss: 1.1946
# Epoch 1/5, Batch 1550, Loss: 1.2290
# Epoch 1/5, Batch 1600, Loss: 1.1320
# Epoch 1/5, Batch 1650, Loss: 1.1819
# Epoch 1/5, Batch 1700, Loss: 0.9363
# Epoch 1/5, Batch 1750, Loss: 1.2691
# Epoch 1/5, Batch 1800, Loss: 0.9668
# Epoch 1/5, Batch 1850, Loss: 0.8385
# Epoch 1/5, Batch 1900, Loss: 1.0454
# Epoch 1/5, Batch 1950, Loss: 1.3571
# Epoch 1/5, Batch 2000, Loss: 1.1593
# Epoch 1/5, Batch 2050, Loss: 1.2760
# Epoch 1/5, Batch 2100, Loss: 1.0291
# Epoch 1/5, Batch 2150, Loss: 1.0513
# Epoch 1/5, Batch 2200, Loss: 0.8749
# Epoch 1/5, Batch 2250, Loss: 1.1096
# Epoch 1/5, Batch 2300, Loss: 1.1863
# Epoch 1/5, Batch 2350, Loss: 0.9652
# Epoch 1/5, Batch 2400, Loss: 1.0450
# Epoch 1/5, Batch 2450, Loss: 1.0967
# Epoch 1/5, Batch 2500, Loss: 1.1571
# Epoch 1/5, Batch 2550, Loss: 0.9302
# Epoch 1/5, Batch 2600, Loss: 1.0262
# Epoch 1/5, Batch 2650, Loss: 1.2933
# Epoch 1/5, Batch 2700, Loss: 1.1114
# Epoch 1/5, Batch 2750, Loss: 1.2724
# Epoch 1/5, Batch 2800, Loss: 1.1704
# Epoch 1/5, Batch 2850, Loss: 1.0689
# Epoch 1/5, Batch 2900, Loss: 1.2028
# Epoch 1/5, Batch 2950, Loss: 1.3109
# Epoch 1/5, Batch 3000, Loss: 0.9747
# Epoch 1/5, Batch 3050, Loss: 1.1986
# Epoch 1/5, Batch 3100, Loss: 1.4304
# Epoch 1/5, Batch 3150, Loss: 1.0555
# Epoch 1/5, Batch 3200, Loss: 1.2495
# Epoch 1/5, Batch 3250, Loss: 1.1951
# Epoch 1/5, Batch 3300, Loss: 1.2274
# Epoch 1/5, Batch 3350, Loss: 1.1232
# Epoch 1/5, Batch 3400, Loss: 1.2766
# Epoch 1/5, Batch 3450, Loss: 1.2561
# Epoch 1/5, Batch 3500, Loss: 1.1984
# Epoch 1/5, Batch 3550, Loss: 1.1371
# Epoch 1/5, Batch 3600, Loss: 1.1492
# Epoch 1/5, Batch 3650, Loss: 1.2789
# Epoch 1/5, Batch 3700, Loss: 1.1908
# Epoch 1/5, Train Loss: 1.1910
# Epoch 1/5, Val Acc: 0.4157, Val F1: 0.3782, Val Precision: 0.4339, Val Recall: 0.4157
# New best model saved with val accuracy: 0.4157
# Epoch 2/5, Batch 0, Loss: 1.1661
# Epoch 2/5, Batch 50, Loss: 1.3023
# Epoch 2/5, Batch 100, Loss: 1.3990
# Epoch 2/5, Batch 150, Loss: 1.4254
# Epoch 2/5, Batch 200, Loss: 1.3822
# Epoch 2/5, Batch 250, Loss: 1.2840
# Epoch 2/5, Batch 300, Loss: 1.4008
# Epoch 2/5, Batch 350, Loss: 1.3295
# Epoch 2/5, Batch 400, Loss: 1.4658
# Epoch 2/5, Batch 450, Loss: 1.3044
# Epoch 2/5, Batch 500, Loss: 1.3376
# Epoch 2/5, Batch 550, Loss: 1.3779
# Epoch 2/5, Batch 600, Loss: 1.3489
# Epoch 2/5, Batch 650, Loss: 1.3577
# Epoch 2/5, Batch 700, Loss: 1.4542
# Epoch 2/5, Batch 750, Loss: 1.2399
# Epoch 2/5, Batch 800, Loss: 1.3666
# Epoch 2/5, Batch 850, Loss: 1.2511
# Epoch 2/5, Batch 900, Loss: 1.3346
# Epoch 2/5, Batch 950, Loss: 1.2913
# Epoch 2/5, Batch 1000, Loss: 1.3128
# Epoch 2/5, Batch 1050, Loss: 1.4143
# Epoch 2/5, Batch 1100, Loss: 1.3685
# Epoch 2/5, Batch 1150, Loss: 1.2456
# Epoch 2/5, Batch 1200, Loss: 1.3410
# Epoch 2/5, Batch 1250, Loss: 1.1638
# Epoch 2/5, Batch 1300, Loss: 1.3062
# Epoch 2/5, Batch 1350, Loss: 1.2437
# Epoch 2/5, Batch 1400, Loss: 1.2135
# Epoch 2/5, Batch 1450, Loss: 1.2190
# Epoch 2/5, Batch 1500, Loss: 1.3127
# Epoch 2/5, Batch 1550, Loss: 1.3190
# Epoch 2/5, Batch 1600, Loss: 1.1879
# Epoch 2/5, Batch 1650, Loss: 1.3356
# Epoch 2/5, Batch 1700, Loss: 1.3031
# Epoch 2/5, Batch 1750, Loss: 1.3323
# Epoch 2/5, Batch 1800, Loss: 1.3036
# Epoch 2/5, Batch 1850, Loss: 1.4014
# Epoch 2/5, Batch 1900, Loss: 1.2441
# Epoch 2/5, Batch 1950, Loss: 1.3660
# Epoch 2/5, Batch 2000, Loss: 1.3920
# Epoch 2/5, Batch 2050, Loss: 1.3426
# Epoch 2/5, Batch 2100, Loss: 1.2974
# Epoch 2/5, Batch 2150, Loss: 1.2872
# Epoch 2/5, Batch 2200, Loss: 1.3228
# Epoch 2/5, Batch 2250, Loss: 1.3269
# Epoch 2/5, Batch 2300, Loss: 1.3342
# Epoch 2/5, Batch 2350, Loss: 1.3142
# Epoch 2/5, Batch 2400, Loss: 1.3480
# Epoch 2/5, Batch 2450, Loss: 1.3635
# Epoch 2/5, Batch 2500, Loss: 1.3826
# Epoch 2/5, Batch 2550, Loss: 1.3369
# Epoch 2/5, Batch 2600, Loss: 1.3920
# Epoch 2/5, Batch 2650, Loss: 1.2987
# Epoch 2/5, Batch 2700, Loss: 1.3591
# Epoch 2/5, Batch 2750, Loss: 1.4221
# Epoch 2/5, Batch 2800, Loss: 1.3463
# Epoch 2/5, Batch 2850, Loss: 1.3803
# Epoch 2/5, Batch 2900, Loss: 1.3375
# Epoch 2/5, Batch 2950, Loss: 1.4331
# Epoch 2/5, Batch 3000, Loss: 1.4551
# Epoch 2/5, Batch 3050, Loss: 1.3040
# Epoch 2/5, Batch 3100, Loss: 1.4754
# Epoch 2/5, Batch 3150, Loss: 1.3126
# Epoch 2/5, Batch 3200, Loss: 1.2758
# Epoch 2/5, Batch 3250, Loss: 1.4021
# Epoch 2/5, Batch 3300, Loss: 1.3397
# Epoch 2/5, Batch 3350, Loss: 1.2524
# Epoch 2/5, Batch 3400, Loss: 1.2992
# Epoch 2/5, Batch 3450, Loss: 1.2838
# Epoch 2/5, Batch 3500, Loss: 1.3021
# Epoch 2/5, Batch 3550, Loss: 1.3828
# Epoch 2/5, Batch 3600, Loss: 1.3810
# Epoch 2/5, Batch 3650, Loss: 1.2832
# Epoch 2/5, Batch 3700, Loss: 1.3149
# Epoch 2/5, Train Loss: 1.3353
# Epoch 2/5, Val Acc: 0.3743, Val F1: 0.3322, Val Precision: 0.3969, Val Recall: 0.3743
# Epoch 3/5, Batch 0, Loss: 1.3928
# Epoch 3/5, Batch 50, Loss: 1.3482
# Epoch 3/5, Batch 100, Loss: 1.3042
# Epoch 3/5, Batch 150, Loss: 1.3378
# Epoch 3/5, Batch 200, Loss: 1.0677
# Epoch 3/5, Batch 250, Loss: 1.3147
# Epoch 3/5, Batch 300, Loss: 1.1743
# Epoch 3/5, Batch 350, Loss: 1.4382
# Epoch 3/5, Batch 400, Loss: 1.2652
# Epoch 3/5, Batch 450, Loss: 1.2563
# Epoch 3/5, Batch 500, Loss: 1.2912
# Epoch 3/5, Batch 550, Loss: 1.3072
# Epoch 3/5, Batch 600, Loss: 1.2450
# Epoch 3/5, Batch 650, Loss: 1.3795
# Epoch 3/5, Batch 700, Loss: 1.3448
# Epoch 3/5, Batch 750, Loss: 1.3292
# Epoch 3/5, Batch 800, Loss: 1.3146
# Epoch 3/5, Batch 850, Loss: 1.3056
# Epoch 3/5, Batch 900, Loss: 1.3572
# Epoch 3/5, Batch 950, Loss: 1.3443
# Epoch 3/5, Batch 1000, Loss: 1.2018
# Epoch 3/5, Batch 1050, Loss: 1.3773
# Epoch 3/5, Batch 1100, Loss: 1.3474
# Epoch 3/5, Batch 1150, Loss: 1.3761
# Epoch 3/5, Batch 1200, Loss: 1.2392
# Epoch 3/5, Batch 1250, Loss: 1.3904
# Epoch 3/5, Batch 1300, Loss: 1.3285
# Epoch 3/5, Batch 1350, Loss: 1.3223
# Epoch 3/5, Batch 1400, Loss: 1.2927
# Epoch 3/5, Batch 1450, Loss: 1.3434
# Epoch 3/5, Batch 1500, Loss: 1.3625
# Epoch 3/5, Batch 1550, Loss: 1.2936
# Epoch 3/5, Batch 1600, Loss: 1.3768
# Epoch 3/5, Batch 1650, Loss: 1.3330
# Epoch 3/5, Batch 1700, Loss: 1.3781
# Epoch 3/5, Batch 1750, Loss: 1.4140
# Epoch 3/5, Batch 1800, Loss: 1.3052
# Epoch 3/5, Batch 1850, Loss: 1.3239
# Epoch 3/5, Batch 1900, Loss: 1.3439
# Epoch 3/5, Batch 1950, Loss: 1.2636
# Epoch 3/5, Batch 2000, Loss: 1.3744
# Epoch 3/5, Batch 2050, Loss: 1.3894
# Epoch 3/5, Batch 2100, Loss: 1.3755
# Epoch 3/5, Batch 2150, Loss: 1.4129
# Epoch 3/5, Batch 2200, Loss: 1.3414
# Epoch 3/5, Batch 2250, Loss: 1.3136
# Epoch 3/5, Batch 2300, Loss: 1.4067
# Epoch 3/5, Batch 2350, Loss: 1.3056
# Epoch 3/5, Batch 2400, Loss: 1.3634
# Epoch 3/5, Batch 2450, Loss: 1.3078
# Epoch 3/5, Batch 2500, Loss: 1.3485
# Epoch 3/5, Batch 2550, Loss: 1.3009
# Epoch 3/5, Batch 2600, Loss: 1.3262
# Epoch 3/5, Batch 2650, Loss: 1.2217
# Epoch 3/5, Batch 2700, Loss: 1.3135
# Epoch 3/5, Batch 2750, Loss: 1.3120
# Epoch 3/5, Batch 2800, Loss: 1.3228
# Epoch 3/5, Batch 2850, Loss: 1.3765
# Epoch 3/5, Batch 2900, Loss: 1.3365
# Epoch 3/5, Batch 2950, Loss: 1.3975
# Epoch 3/5, Batch 3000, Loss: 1.3767
# Epoch 3/5, Batch 3050, Loss: 1.3088
# Epoch 3/5, Batch 3100, Loss: 1.2923
# Epoch 3/5, Batch 3150, Loss: 1.2462
# Epoch 3/5, Batch 3200, Loss: 1.3231
# Epoch 3/5, Batch 3250, Loss: 1.3137
# Epoch 3/5, Batch 3300, Loss: 1.3627
# Epoch 3/5, Batch 3350, Loss: 1.3494
# Epoch 3/5, Batch 3400, Loss: 1.2925
# Epoch 3/5, Batch 3450, Loss: 1.3741
# Epoch 3/5, Batch 3500, Loss: 1.3815
# Epoch 3/5, Batch 3550, Loss: 1.4113
# Epoch 3/5, Batch 3600, Loss: 1.3277
# Epoch 3/5, Batch 3650, Loss: 1.2970
# Epoch 3/5, Batch 3700, Loss: 1.3711
# Epoch 3/5, Train Loss: 1.3346
# Epoch 3/5, Val Acc: 0.3314, Val F1: 0.2813, Val Precision: 0.3684, Val Recall: 0.3314
# Epoch 4/5, Batch 0, Loss: 1.3561
# Epoch 4/5, Batch 50, Loss: 1.3063
# Epoch 4/5, Batch 100, Loss: 1.4659
# Epoch 4/5, Batch 150, Loss: 1.3714
# Epoch 4/5, Batch 200, Loss: 1.3350
# Epoch 4/5, Batch 250, Loss: 1.2056
# Epoch 4/5, Batch 300, Loss: 1.3720
# Epoch 4/5, Batch 350, Loss: 1.3567
# Epoch 4/5, Batch 400, Loss: 1.3061
# Epoch 4/5, Batch 450, Loss: 1.3361
# Epoch 4/5, Batch 500, Loss: 1.3509
# Epoch 4/5, Batch 550, Loss: 1.3919
# Epoch 4/5, Batch 600, Loss: 1.3041
# Epoch 4/5, Batch 650, Loss: 1.2784
# Epoch 4/5, Batch 700, Loss: 1.2959
# Epoch 4/5, Batch 750, Loss: 1.4277
# Epoch 4/5, Batch 800, Loss: 1.3406
# Epoch 4/5, Batch 850, Loss: 1.3270
# Epoch 4/5, Batch 900, Loss: 1.3668
# Epoch 4/5, Batch 950, Loss: 1.3497
# Epoch 4/5, Batch 1000, Loss: 1.4210
# Epoch 4/5, Batch 1050, Loss: 1.3636
# Epoch 4/5, Batch 1100, Loss: 1.3603
# Epoch 4/5, Batch 1150, Loss: 1.2468
# Epoch 4/5, Batch 1200, Loss: 1.4211
# Epoch 4/5, Batch 1250, Loss: 1.2258
# Epoch 4/5, Batch 1300, Loss: 1.3369
# Epoch 4/5, Batch 1350, Loss: 1.4916
# Epoch 4/5, Batch 1400, Loss: 1.3852
# Epoch 4/5, Batch 1450, Loss: 1.3118
# Epoch 4/5, Batch 1500, Loss: 1.3607
# Epoch 4/5, Batch 1550, Loss: 1.3914
# Epoch 4/5, Batch 1600, Loss: 1.2861
# Epoch 4/5, Batch 1650, Loss: 1.3435
# Epoch 4/5, Batch 1700, Loss: 1.2442
# Epoch 4/5, Batch 1750, Loss: 1.2894
# Epoch 4/5, Batch 1800, Loss: 1.3680
# Epoch 4/5, Batch 1850, Loss: 1.3463
# Epoch 4/5, Batch 1900, Loss: 1.3345
# Epoch 4/5, Batch 1950, Loss: 1.3378
# Epoch 4/5, Batch 2000, Loss: 1.2371
# Epoch 4/5, Batch 2050, Loss: 1.3915
# Epoch 4/5, Batch 2100, Loss: 1.3083
# Epoch 4/5, Batch 2150, Loss: 1.4552
# Epoch 4/5, Batch 2200, Loss: 1.4792
# Epoch 4/5, Batch 2250, Loss: 1.2667
# Epoch 4/5, Batch 2300, Loss: 1.3232
# Epoch 4/5, Batch 2350, Loss: 1.1929
# Epoch 4/5, Batch 2400, Loss: 1.2809
# Epoch 4/5, Batch 2450, Loss: 1.2997
# Epoch 4/5, Batch 2500, Loss: 1.3103
# Epoch 4/5, Batch 2550, Loss: 1.3205
# Epoch 4/5, Batch 2600, Loss: 1.2889
# Epoch 4/5, Batch 2650, Loss: 1.4341
# Epoch 4/5, Batch 2700, Loss: 1.3382
# Epoch 4/5, Batch 2750, Loss: 1.3305
# Epoch 4/5, Batch 2800, Loss: 1.2392
# Epoch 4/5, Batch 2850, Loss: 1.3428
# Epoch 4/5, Batch 2900, Loss: 1.3129
# Epoch 4/5, Batch 2950, Loss: 1.2150
# Epoch 4/5, Batch 3000, Loss: 1.2704
# Epoch 4/5, Batch 3050, Loss: 1.2391
# Epoch 4/5, Batch 3100, Loss: 1.3474
# Epoch 4/5, Batch 3150, Loss: 1.2910
# Epoch 4/5, Batch 3200, Loss: 1.3660
# Epoch 4/5, Batch 3250, Loss: 1.2809
# Epoch 4/5, Batch 3300, Loss: 1.2336
# Epoch 4/5, Batch 3350, Loss: 1.2633
# Epoch 4/5, Batch 3400, Loss: 1.3354
# Epoch 4/5, Batch 3450, Loss: 1.3218
# Epoch 4/5, Batch 3500, Loss: 1.3921
# Epoch 4/5, Batch 3550, Loss: 1.2725
# Epoch 4/5, Batch 3600, Loss: 1.4068
# Epoch 4/5, Batch 3650, Loss: 1.2995
# Epoch 4/5, Batch 3700, Loss: 1.3317
# Epoch 4/5, Train Loss: 1.3316
# Epoch 4/5, Val Acc: 0.3671, Val F1: 0.3113, Val Precision: 0.3460, Val Recall: 0.3671
# Epoch 5/5, Batch 0, Loss: 1.1923
# Epoch 5/5, Batch 50, Loss: 1.3365
# Epoch 5/5, Batch 100, Loss: 1.3536
# Epoch 5/5, Batch 150, Loss: 1.3072
# Epoch 5/5, Batch 200, Loss: 1.3462
# Epoch 5/5, Batch 250, Loss: 1.2378
# Epoch 5/5, Batch 300, Loss: 1.3826
# Epoch 5/5, Batch 350, Loss: 1.3131
# Epoch 5/5, Batch 400, Loss: 1.3157
# Epoch 5/5, Batch 450, Loss: 1.3617
# Epoch 5/5, Batch 500, Loss: 1.2866
# Epoch 5/5, Batch 550, Loss: 1.2140
# Epoch 5/5, Batch 600, Loss: 1.4018
# Epoch 5/5, Batch 650, Loss: 1.2675
# Epoch 5/5, Batch 700, Loss: 1.2557
# Epoch 5/5, Batch 750, Loss: 1.3424
# Epoch 5/5, Batch 800, Loss: 1.2746
# Epoch 5/5, Batch 850, Loss: 1.3613
# Epoch 5/5, Batch 900, Loss: 1.3201
# Epoch 5/5, Batch 950, Loss: 1.3441
# Epoch 5/5, Batch 1000, Loss: 1.2259
# Epoch 5/5, Batch 1050, Loss: 1.2315
# Epoch 5/5, Batch 1100, Loss: 1.3994
# Epoch 5/5, Batch 1150, Loss: 1.1970
# Epoch 5/5, Batch 1200, Loss: 1.3408
# Epoch 5/5, Batch 1250, Loss: 1.2782
# Epoch 5/5, Batch 1300, Loss: 1.3371
# Epoch 5/5, Batch 1350, Loss: 1.1831
# Epoch 5/5, Batch 1400, Loss: 1.2018
# Epoch 5/5, Batch 1450, Loss: 1.1925
# Epoch 5/5, Batch 1500, Loss: 1.3102
# Epoch 5/5, Batch 1550, Loss: 1.2051
# Epoch 5/5, Batch 1600, Loss: 1.3469
# Epoch 5/5, Batch 1650, Loss: 1.4006
# Epoch 5/5, Batch 1700, Loss: 1.2805
# Epoch 5/5, Batch 1750, Loss: 1.3670
# Epoch 5/5, Batch 1800, Loss: 1.2883
# Epoch 5/5, Batch 1850, Loss: 1.3244
# Epoch 5/5, Batch 1900, Loss: 1.2290
# Epoch 5/5, Batch 1950, Loss: 1.3470
# Epoch 5/5, Batch 2000, Loss: 1.3282
# Epoch 5/5, Batch 2050, Loss: 1.1303
# Epoch 5/5, Batch 2100, Loss: 1.3432
# Epoch 5/5, Batch 2150, Loss: 1.2459
# Epoch 5/5, Batch 2200, Loss: 1.2246
# Epoch 5/5, Batch 2250, Loss: 1.3594
# Epoch 5/5, Batch 2300, Loss: 1.3281
# Epoch 5/5, Batch 2350, Loss: 1.2391
# Epoch 5/5, Batch 2400, Loss: 1.2864
# Epoch 5/5, Batch 2450, Loss: 1.3089
# Epoch 5/5, Batch 2500, Loss: 1.1824
# Epoch 5/5, Batch 2550, Loss: 1.3616
# Epoch 5/5, Batch 2600, Loss: 1.3231
# Epoch 5/5, Batch 2650, Loss: 1.2826
# Epoch 5/5, Batch 2700, Loss: 1.2286
# Epoch 5/5, Batch 2750, Loss: 1.3532
# Epoch 5/5, Batch 2800, Loss: 1.3242
# Epoch 5/5, Batch 2850, Loss: 1.2027
# Epoch 5/5, Batch 2900, Loss: 1.1782
# Epoch 5/5, Batch 2950, Loss: 1.2090
# Epoch 5/5, Batch 3000, Loss: 1.3335
# Epoch 5/5, Batch 3050, Loss: 1.1991
# Epoch 5/5, Batch 3100, Loss: 1.3043
# Epoch 5/5, Batch 3150, Loss: 1.4477
# Epoch 5/5, Batch 3200, Loss: 1.2174
# Epoch 5/5, Batch 3250, Loss: 1.3135
# Epoch 5/5, Batch 3300, Loss: 1.3284
# Epoch 5/5, Batch 3350, Loss: 1.2779
# Epoch 5/5, Batch 3400, Loss: 1.1774
# Epoch 5/5, Batch 3450, Loss: 1.3441
# Epoch 5/5, Batch 3500, Loss: 1.4231
# Epoch 5/5, Batch 3550, Loss: 1.3356
# Epoch 5/5, Batch 3600, Loss: 1.2398
# Epoch 5/5, Batch 3650, Loss: 1.2498
# Epoch 5/5, Batch 3700, Loss: 1.2309
# Epoch 5/5, Train Loss: 1.3013
# Epoch 5/5, Val Acc: 0.3329, Val F1: 0.2744, Val Precision: 0.4579, Val Recall: 0.3329
# Test Accuracy: 0.4157
# Test F1 Score: 0.3782
# Test Precision: 0.4339
# Test Recall: 0.4157
#
# Best lambda mode: frozen
# Best accuracy: 0.8930

# %% [markdown]
# # Analysis Report on ELMo Implementation for News Classification
#
# ## Introduction
#
# This report analyzes the performance of different lambda weight configurations in an ELMo (Embeddings from Language Models) implementation for the AG News Classification dataset. The analysis is based on validation accuracy measurements across different lambda modes over 4 training epochs.
#
# ## Data Analysis
#
# The graph shows validation accuracy for three different lambda configuration methods:
# - **Trainable λs**: Weights that are learned during training
# - **Frozen λs**: Randomly initialized weights that remain fixed
# - **Learnable Function**: A function that combines representations across layers
#
# ### Performance Comparison
#
# 1. **Trainable and Frozen λs**:
#    - Both methods achieve similar high performance (approximately 88-90% accuracy)
#    - They show slight improvement over epochs, indicating stable learning
#    - The trainable configuration slightly outperforms the frozen configuration
#
# 2. **Learnable Function**:
#    - Significantly underperforms compared to the other methods (~33-41% accuracy)
#    - Shows unstable learning with fluctuations across
#    - Has a generally decreasing trend, suggesting potential issues with the implementation
#
# ## Key Observations
#
# 1. **Similar Performance of Trainable and Frozen λs**:
#    The close performance between trainable and frozen weights suggests that the pre-trained ELMo embeddings already contain effective representations, regardless of whether the combination weights are optimized during fine-tuning or fixed.
#
# 2. **Poor Performance of Learnable Function**:
#    The significantly lower accuracy of the learnable function approach indicates implementation issues. Potential problems could include:
#    - Overly complex function architecture leading to overfitting
#    - Gradient instability during training
#    - Inappropriate function design for this specific task
#
# 3. **Stability**:
#    The trainable and frozen approaches show consistent performance, whereas the learnable function shows more variation, suggesting less reliability.
#
# ## Recommendations
#
# 1. **Preferred Configuration**: Based on the results, the trainable λs approach should be preferred as it provides the best overall performance while allowing the model to adapt the weights to the specific task.
#
# 2. **Investigation of Learnable Function**: Further investigation into the learnable function approach is needed to understand its underperformance:
#    - Try different architectural designs for the function
#    - Apply regularization techniques to prevent potential overfitting
#    - Check for implementation errors or training instabilities
#
# 3. **Additional Metrics**: While accuracy provides a good overview, analyzing additional metrics such as F1 score, precision, and recall would give more insight, especially if the classes are imbalanced.
#
# ## Conclusion
#
# The ELMo implementation with either trainable or frozen λs performs well on the news classification task, achieving approximately 90% accuracy. This confirms the effectiveness of using contextual embeddings from ELMo for text classification tasks. However, the learnable function approach requires significant improvement or redesign to be competitive with the simpler weighting strategies.

# %%
import torch
import torch.nn as nn
import pickle
import nltk
from nltk.tokenize import word_tokenize

# Import ELMo model and classification model
from ELMO import ELMoEmbedding
from classification import ClassificationModel

nltk.download('punkt_tab')

def load_models(model_path):
    # Load vocabulary
    with open('/content/vocab.pkl', 'rb') as f:
        vocab_data = pickle.load(f)
    word_to_idx = vocab_data['word_to_idx']
    vocab = vocab_data['vocab']

    # Set device
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Load pretrained ELMo model
    vocab_size = len(word_to_idx)
    embedding_dim = 1024
    hidden_dim = 512
    elmo_model = ELMoEmbedding(vocab_size, embedding_dim, hidden_dim)
    elmo_model.load_state_dict(torch.load('/content/bilstm.pt', map_location=device))
    elmo_model = elmo_model.to(device)

    # Load classification model
    classifier = ClassificationModel(elmo_model, hidden_dim=hidden_dim, num_classes=4)

    # Load state dict with strict=False to ignore unexpected keys
    classifier.load_state_dict(torch.load(model_path, map_location=device), strict=False)
    classifier = classifier.to(device)
    classifier.eval()

    return classifier, word_to_idx, device


def preprocess_text(text, word_to_idx, max_len=100):
    # Tokenize
    tokens = word_tokenize(text.lower())

    # Truncate
    if len(tokens) > max_len:
        tokens = tokens[:max_len]

    # Convert to indices
    pad_idx = word_to_idx['<PAD>']
    unk_idx = word_to_idx['<UNK>']
    indices = [word_to_idx.get(word, unk_idx) for word in tokens]

    # Pad to max_len
    indices = indices + [pad_idx] * (max_len - len(indices))

    return torch.tensor([indices], dtype=torch.long)


def predict(model, text, word_to_idx, device):
    # Preprocess text
    inputs = preprocess_text(text, word_to_idx)
    inputs = inputs.to(device)

    # Generate predictions
    with torch.no_grad():
        logits = model(inputs)
        probs = torch.softmax(logits, dim=1)[0]

    # Class mapping
    class_mapping = {
        0: "World",
        1: "Sports",
        2: "Business",
        3: "Sci/Tech"
    }

    # Print results
    for i, prob in enumerate(probs):
        print(f"{class_mapping[i]} {prob.item():.4f}")

    return probs.cpu().numpy()


# Replace command line arguments with explicit values
model_path = '/content/classifier.pt'  # Update with your actual model path
description = 'Your article text here'  # Replace with your text

# Load models
model, word_to_idx, device = load_models(model_path)

# Make prediction
predict(model, description, word_to_idx, device)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Initializing dim_adapter with input size: 1024
# World 0.8954
# Sports 0.0000
# Business 0.1035
# Sci/Tech 0.0011
# array([8.9537078e-01, 7.1730923e-08, 1.0353520e-01, 1.0940285e-03],
#       dtype=float32)

# %% [markdown]
# ## Comparing Traditional Embeddings with ELMo Variants
#
# The validation accuracy graph presents an interesting contradiction when compared with the report's findings. While the report indicates that traditional embedding methods (Skip-gram at 88.83% and CBOW at 88.07%) outperformed all ELMo variants, the graph shows ELMo with trainable and frozen λs achieving approximately 88-90% accuracy. This represents a potential discrepancy between the visualized results and the tabulated findings.
#
# Most notably, the graph shows that both trainable and frozen λs configurations perform similarly and maintain consistently high accuracy (88-90%) across all epochs. This performance appears to match or even slightly exceed the reported accuracy of Skip-gram (88.83%), contradicting the conclusion that traditional embeddings outperformed ELMo variants.
#
# The most striking discrepancy involves the learnable function approach. According to the report, this ELMo variant achieved 87.33% accuracy, making it competitive with other approaches. However, the graph shows this method dramatically underperforming at approximately 33-41% accuracy. This significant performance gap likely stems from overfitting in the learnable function implementation. Since news classification is a relatively straightforward task that can be effectively handled with simpler models, the additional complexity introduced by the neural network function for combining ELMo layers may be capturing noise rather than meaningful patterns. The decline in accuracy across epochs further supports this overfitting hypothesis, suggesting the learnable function became increasingly specialized to training data characteristics that didn't generalize to the validation set. This demonstrates that for simpler NLP tasks, more complex models don't necessarily yield better results and can actually harm performance through overfitting.
#
# These contradictory findings highlight the importance of matching model complexity to task requirements when selecting embedding techniques for text classification tasks.

# %% [markdown]
# https://drive.google.com/file/d/1VVL4LyvtrAy4I70MdO8AeqV-VCwgxsf9/view?usp=sharing
